# %%
import pandas as pd
import os
import openpyxl
import numpy as np
import re
from datetime import datetime
from nltk.stem import WordNetLemmatizer
from nltk import pos_tag
from nltk.corpus import wordnet
lemmatizer = WordNetLemmatizer()

# %%
class FinancialReport():
    def __init__(self,file):
        self.file = file
        self.readFile()
        self.findBalanceSheet()
        self.findCashFlowSheet()
    def readFile(self):
        path = os.path.join("financial statements",self.file)
        self.statements = pd.read_excel(path,sheet_name=None)
    def getSheetNames(self):
        return self.statements.keys()
    def findBalanceSheet(self):
        balanceSheetName = [name for name in self.getSheetNames() if "BALANCE" in name][0]
        self.balance = self.statements[balanceSheetName]
        self.balance.columns = ["label"]+list(self.balance.columns[1:])
    def findCashFlowSheet(self):
        cashflowSheetName = [name for name in self.getSheetNames() if "CASH" in name]
        if len(cashflowSheetName) > 0:
            self.cashflow = self.statements[cashflowSheetName[0]]
        else:
            cashflowSheetName = [name for name in self.getSheetNames() if "CONDENSED" in name][-1]
            self.cashflow = self.statements[cashflowSheetName]
        self.cashflow.columns = self.cashflow.iloc[0]
        self.cashflow = self.cashflow.drop(0)
        self.cashflow.columns = ["label"]+list(self.cashflow.columns[1:])
    def getBalanceSheet(self):
        return self.balance
    def getCashFlowSheet(self):
        return self.cashflow

# %%
class CashFlow():
    def __init__(self):
        self.finalCashFlow = pd.DataFrame(columns=["title","num_title","label"])
        self.setFinancialStatements()
        self.addDataToCashFlowSheet()
        self.setQuarters()
        self.rearrangeFinalCashFlowSheet()
        
        
    def getFiles(self):
        files = os.listdir("financial statements")
        files.remove(".DS_Store")
        files = [file for file in files if file[0] != "~"]
        return files

    def setFinancialStatements(self):
        self.files = self.getFiles()
        self.FinancialReports = [FinancialReport(file) for file in self.files]
        
    def addDataToCashFlowSheet(self):
        
        for FinancialStatements in self.FinancialReports:
            print(FinancialStatements.file)
            cashflow = FinancialStatements.getCashFlowSheet().copy()
            
            cols = ["label"]+[col for col in cashflow.columns[1:] if col not in self.finalCashFlow.columns] ## remove columns of data already in main balance sheet
            cashflow = cashflow[cols]
            
            cashflow = self.parseCashFlowStatement(cashflow)
            
            self.finalCashFlow = pd.merge(self.finalCashFlow, cashflow, how="outer",on=["label","title"],suffixes=('', '_new'))
            #self.finalCashFlow.title = [self.finalCashFlow.title[i] if not pd.isnull(self.finalCashFlow.title[i]) else self.finalCashFlow.title_new[i] for i in range(len(self.finalCashFlow))] #merge titles
            self.finalCashFlow.num_title = [self.merge_number(self.finalCashFlow.num_title[i],self.finalCashFlow.num_title_new[i]) for i in range(len(self.finalCashFlow))] #merge the number for the titles. use greatest num bc bigger num means there is section before it
            self.finalCashFlow = self.finalCashFlow.drop(["num_title_new"],axis=1)

    def rearrangeFinalCashFlowSheet(self):
        self.finalCashFlow = self.finalCashFlow.replace(" ",np.nan)

        # put Nets at the bottom of each section
        Nets = self.finalCashFlow.loc[self.finalCashFlow.label.str.startswith("net")].reset_index(drop=True) 
        self.finalCashFlow = self.finalCashFlow.loc[~self.finalCashFlow.label.str.startswith("net")].reset_index(drop=True)
        self.finalCashFlow = pd.concat([self.finalCashFlow,Nets]) 
        self.finalCashFlow = self.finalCashFlow.reset_index(drop=True).reset_index().rename(columns={"index":"num_label"})
        self.finalCashFlow = self.finalCashFlow.sort_values(["num_title","num_label"]) # order by title and then location
        self.finalCashFlow = self.finalCashFlow.drop(["num_label"],axis=1).reset_index(drop=True).reset_index().rename(columns={"index":"num_label"})

    def parseCashFlowStatement(self,balance):
        num = 0
        index = []
        title = False
        for label in balance.label:
            if ":" in label:
                title = re.sub("\([\w\W]+\)","",label[:-1]).replace("  "," ").strip()
                num += 1
                continue
            if title:
                label = label.lower()
                index.append([title,num,label])
            
            if "net" == label[:3]:
                title = np.nan
                num += 1

        balance = balance.loc[balance.label.isin(np.array(index)[:,2])].copy()
        balance.loc[:,["title","num_title","label"]] = list(index)
        balance = balance.set_index(["title","num_title","label"]).reset_index()
        return balance
    
    def clean_up_string(self,string):
        string = string.strip()
        space_positions = [x.start() for x in re.finditer('\ ',  string)]
        for i in reversed(space_positions):
            if string[i+1:] in ["of", "and"]:
                string = string[:i]
        return string
    
    def merge_number(self,a,b):
        if pd.isnull(a):
            return b
        if pd.isnull(b):
            return a
        return max(a,b)
    
    def setQuarters(self):
        dates = list(self.finalCashFlow.columns[3:])
        dates.sort(key=lambda date: datetime.strptime(date.replace(".",""), '%b %d, %Y'))
        self.finalCashFlow = self.finalCashFlow[["title","label","num_title"]+dates]
        self.finalCashFlow.columns = ["title","label","num_title"]+[self.parseQuarter(date) for date in self.finalCashFlow.columns[3:]]
    def parseQuarter(self,date):
        mo = date.split(" ")[0].strip(".")
        year = date.split(", ")[-1]
        if mo in ["May"]:
            return "Q1 "+str(int(year)+1)
        
        if mo in ["Jul","Aug"]:
            return "Q2 "+str(int(year)+1)
        
        if mo in ["Oct","Nov"]:
            return "Q3 "+str(int(year)+1)
        
        if mo in ["Jan","Feb"]:
            return "Q4 "+str(int(year))

# %%
cashflow = CashFlow()
finalCashFlow = cashflow.finalCashFlow
finalCashFlow
# Out:
# q3 2021.xlsx
#     num_title                                              title  \
# 0           1               Cash flows from operating activities
# 1           3  Adjustments to reconcile net income to net cas...
# 2           3  Adjustments to reconcile net income to net cas...
# 3           3  Adjustments to reconcile net income to net cas...
# 4           3  Adjustments to reconcile net income to net cas...
# 5           3  Adjustments to reconcile net income to net cas...
# 6           3  Adjustments to reconcile net income to net cas...
# 7           3  Adjustments to reconcile net income to net cas...
# 8           3  Adjustments to reconcile net income to net cas...
# 9           3  Adjustments to reconcile net income to net cas...
# 10          4        Changes in operating assets and liabilities
# 11          4        Changes in operating assets and liabilities
# 12          4        Changes in operating assets and liabilities
# 13          4        Changes in operating assets and liabilities
# 14          4        Changes in operating assets and liabilities
# 15          4        Changes in operating assets and liabilities
# 16          4        Changes in operating assets and liabilities
# 17          4        Changes in operating assets and liabilities
# 18          6               Cash flows from investing activities
# 19          6               Cash flows from investing activities
# 20          6               Cash flows from investing activities
# 21          6               Cash flows from investing activities
# 22          6               Cash flows from investing activities
# 23          7                                                NaN
# 24          7                                                NaN
# 25          9               Cash flows from financing activities
# 26          9               Cash flows from financing activities
# 27          9               Cash flows from financing activities
# 28          9               Cash flows from financing activities
# 29          9               Cash flows from financing activities
# 30          9               Cash flows from financing activities
# 31          9               Cash flows from financing activities
# 32          9               Cash flows from financing activities
# 33          9               Cash flows from financing activities
# 34          9               Cash flows from financing activities
# 35         10                                                NaN
# 36         10                                                NaN
# 37         10                                                NaN
# 38         10                                                NaN
# 39         11   Supplemental disclosure of cash flow information
# 40         11   Supplemental disclosure of cash flow information
#
#                                                 label Oct. 30, 2021  \
# 0                                   net income (loss)           NaN
# 1                       depreciation and amortization           NaN
# 2                            share-based compensation           NaN
# 3                    operating lease, impairment loss           NaN
# 4                      other asset impairment charges           NaN
# 5               gain (loss) on extinguishment of debt           NaN
# 6                 amortization of debt issuance costs           NaN
# 7                            non-cash and other items           NaN
# 8              gain (loss) on disposition of business           NaN
# 9                               deferred income taxes           NaN
# 10                              merchandise inventory           NaN
# 11    other current assets and other long-term assets           NaN
# 12                                   accounts payable           NaN
# 13     accrued expenses and other current liabilities           NaN
# 14  income taxes payable, net of receivables and o...           NaN
# 15   lease incentives and other long-term liabilities           NaN
# 16        operating lease assets and liabilities, net           NaN
# 17  net cash provided by (used for) operating acti...           NaN
# 18                purchases of property and equipment           NaN
# 19         payments to acquire short-term investments           NaN
# 20  proceeds from sale, maturity and collection of...           NaN
# 21  payments for acquisition activity, net of cash...           NaN
# 22             net cash paid for divestiture activity           NaN
# 23                                              other           NaN
# 24  net cash provided by (used for) investing acti...           NaN
# 25                      proceeds from lines of credit           NaN
# 26  proceeds from issuances under share-based comp...           NaN
# 27  withholding tax payments related to vesting of...           NaN
# 28                        repurchases of common stock           NaN
# 29                                cash dividends paid           NaN
# 30           proceeds from issuance of long-term debt           NaN
# 31                        payments to extinguish debt           NaN
# 32                   payments for debt issuance costs           NaN
# 33                      repayments of lines of credit           NaN
# 34  net cash provided by (used for) financing acti...           NaN
# 35  effect of exchange rate on cash, cash equivale...           NaN
# 36  cash, cash equivalents, restricted cash and re...           NaN
# 37  cash, cash equivalents, restricted cash and re...           NaN
# 38  cash, cash equivalents, restricted cash and re...           NaN
# 39  interest paid, excluding capitalized interest,...           NaN
# 40  cash paid for income taxes during the period, ...           NaN
#
#    Oct. 31, 2020
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# 5            NaN
# 6            NaN
# 7            NaN
# 8            NaN
# 9            NaN
# 10           NaN
# 11           NaN
# 12           NaN
# 13           NaN
# 14           NaN
# 15           NaN
# 16           NaN
# 17           NaN
# 18           NaN
# 19           NaN
# 20           NaN
# 21           NaN
# 22           NaN
# 23           NaN
# 24           NaN
# 25           NaN
# 26           NaN
# 27           NaN
# 28           NaN
# 29           NaN
# 30           NaN
# 31           NaN
# 32           NaN
# 33           NaN
# 34           NaN
# 35           NaN
# 36           NaN
# 37           NaN
# 38           NaN
# 39           NaN
# 40           NaN
# q3 2020.xlsx
#     num_title                                              title  \
# 0         1.0               Cash flows from operating activities
# 1         3.0  Adjustments to reconcile net income to net cas...
# 2         3.0  Adjustments to reconcile net income to net cas...
# 3         3.0  Adjustments to reconcile net income to net cas...
# 4         3.0  Adjustments to reconcile net income to net cas...
# 5         3.0  Adjustments to reconcile net income to net cas...
# 6         3.0  Adjustments to reconcile net income to net cas...
# 7         3.0  Adjustments to reconcile net income to net cas...
# 8         3.0  Adjustments to reconcile net income to net cas...
# 9         3.0  Adjustments to reconcile net income to net cas...
# 10        4.0        Changes in operating assets and liabilities
# 11        4.0        Changes in operating assets and liabilities
# 12        4.0        Changes in operating assets and liabilities
# 13        4.0        Changes in operating assets and liabilities
# 14        4.0        Changes in operating assets and liabilities
# 15        4.0        Changes in operating assets and liabilities
# 16        4.0        Changes in operating assets and liabilities
# 17        4.0        Changes in operating assets and liabilities
# 18        6.0               Cash flows from investing activities
# 19        6.0               Cash flows from investing activities
# 20        6.0               Cash flows from investing activities
# 21        6.0               Cash flows from investing activities
# 22        6.0               Cash flows from investing activities
# 23        7.0                                                NaN
# 24        7.0                                                NaN
# 25        9.0               Cash flows from financing activities
# 26        9.0               Cash flows from financing activities
# 27        9.0               Cash flows from financing activities
# 28        9.0               Cash flows from financing activities
# 29        9.0               Cash flows from financing activities
# 30        9.0               Cash flows from financing activities
# 31        9.0               Cash flows from financing activities
# 32        9.0               Cash flows from financing activities
# 33        9.0               Cash flows from financing activities
# 34        9.0               Cash flows from financing activities
# 35       10.0                                                NaN
# 36       10.0                                                NaN
# 37       10.0                                                NaN
# 38       10.0                                                NaN
# 39       11.0   Supplemental disclosure of cash flow information
# 40       11.0   Supplemental disclosure of cash flow information
# 41        3.0  Adjustments to reconcile net income to net cas...
# 42        6.0               Cash flows from investing activities
# 43        6.0               Cash flows from investing activities
# 44        6.0               Cash flows from investing activities
# 45        6.0               Cash flows from investing activities
# 46        6.0               Cash flows from investing activities
# 47        8.0               Cash flows from financing activities
# 48        8.0               Cash flows from financing activities
#
#                                                 label Oct. 30, 2021  \
# 0                                   net income (loss)           NaN
# 1                       depreciation and amortization           NaN
# 2                            share-based compensation           NaN
# 3                    operating lease, impairment loss           NaN
# 4                      other asset impairment charges           NaN
# 5               gain (loss) on extinguishment of debt           NaN
# 6                 amortization of debt issuance costs           NaN
# 7                            non-cash and other items           NaN
# 8              gain (loss) on disposition of business           NaN
# 9                               deferred income taxes           NaN
# 10                              merchandise inventory           NaN
# 11    other current assets and other long-term assets           NaN
# 12                                   accounts payable           NaN
# 13     accrued expenses and other current liabilities           NaN
# 14  income taxes payable, net of receivables and o...           NaN
# 15   lease incentives and other long-term liabilities           NaN
# 16        operating lease assets and liabilities, net           NaN
# 17  net cash provided by (used for) operating acti...           NaN
# 18                purchases of property and equipment           NaN
# 19         payments to acquire short-term investments           NaN
# 20  proceeds from sale, maturity and collection of...           NaN
# 21  payments for acquisition activity, net of cash...           NaN
# 22             net cash paid for divestiture activity           NaN
# 23                                              other           NaN
# 24  net cash provided by (used for) investing acti...           NaN
# 25                      proceeds from lines of credit           NaN
# 26  proceeds from issuances under share-based comp...           NaN
# 27  withholding tax payments related to vesting of...           NaN
# 28                        repurchases of common stock           NaN
# 29                                cash dividends paid           NaN
# 30           proceeds from issuance of long-term debt           NaN
# 31                        payments to extinguish debt           NaN
# 32                   payments for debt issuance costs           NaN
# 33                      repayments of lines of credit           NaN
# 34  net cash provided by (used for) financing acti...           NaN
# 35  effect of exchange rate on cash, cash equivale...           NaN
# 36  cash, cash equivalents, restricted cash and re...           NaN
# 37  cash, cash equivalents, restricted cash and re...           NaN
# 38  cash, cash equivalents, restricted cash and re...           NaN
# 39  interest paid, excluding capitalized interest,...           NaN
# 40  cash paid for income taxes during the period, ...           NaN
# 41  gain (loss) on disposition of property plant e...           NaN
# 42                    proceeds from sale of buildings           NaN
# 43  payments to acquire businesses, net of cash ac...           NaN
# 44                      payments to acquire buildings           NaN
# 45                                              other           NaN
# 46  net cash provided by (used for) investing acti...           NaN
# 47                       repayments of long-term debt           NaN
# 48                    payments of debt issuance costs           NaN
#
#    Oct. 31, 2020 Nov. 02, 2019
# 0            NaN           NaN
# 1            NaN           NaN
# 2            NaN           NaN
# 3            NaN           NaN
# 4            NaN           NaN
# 5            NaN           NaN
# 6            NaN           NaN
# 7            NaN           NaN
# 8            NaN           NaN
# 9            NaN           NaN
# 10           NaN           NaN
# 11           NaN           NaN
# 12           NaN           NaN
# 13           NaN           NaN
# 14           NaN           NaN
# 15           NaN           NaN
# 16           NaN           NaN
# 17           NaN           NaN
# 18           NaN           NaN
# 19           NaN           NaN
# 20           NaN           NaN
# 21           NaN           NaN
# 22           NaN           NaN
# 23           NaN           NaN
# 24           NaN           NaN
# 25           NaN           NaN
# 26           NaN           NaN
# 27           NaN           NaN
# 28           NaN           NaN
# 29           NaN           NaN
# 30           NaN           NaN
# 31           NaN           NaN
# 32           NaN           NaN
# 33           NaN           NaN
# 34           NaN           NaN
# 35           NaN           NaN
# 36           NaN           NaN
# 37           NaN           NaN
# 38           NaN           NaN
# 39           NaN           NaN
# 40           NaN           NaN
# 41           NaN           NaN
# 42           NaN           NaN
# 43           NaN           NaN
# 44           NaN           NaN
# 45           NaN           NaN
# 46           NaN           NaN
# 47           NaN           NaN
# 48           NaN           NaN
# q1 2019.xlsx
#     num_title                                              title  \
# 0         1.0               Cash flows from operating activities
# 1         3.0  Adjustments to reconcile net income to net cas...
# 2         3.0  Adjustments to reconcile net income to net cas...
# 3         3.0  Adjustments to reconcile net income to net cas...
# 4         3.0  Adjustments to reconcile net income to net cas...
# 5         3.0  Adjustments to reconcile net income to net cas...
# 6         3.0  Adjustments to reconcile net income to net cas...
# 7         3.0  Adjustments to reconcile net income to net cas...
# 8         3.0  Adjustments to reconcile net income to net cas...
# 9         3.0  Adjustments to reconcile net income to net cas...
# 10        4.0        Changes in operating assets and liabilities
# 11        4.0        Changes in operating assets and liabilities
# 12        4.0        Changes in operating assets and liabilities
# 13        4.0        Changes in operating assets and liabilities
# 14        4.0        Changes in operating assets and liabilities
# 15        4.0        Changes in operating assets and liabilities
# 16        4.0        Changes in operating assets and liabilities
# 17        4.0        Changes in operating assets and liabilities
# 18        6.0               Cash flows from investing activities
# 19        6.0               Cash flows from investing activities
# 20        6.0               Cash flows from investing activities
# 21        6.0               Cash flows from investing activities
# 22        6.0               Cash flows from investing activities
# 23        7.0                                                NaN
# 24        7.0                                                NaN
# 25        9.0               Cash flows from financing activities
# 26        9.0               Cash flows from financing activities
# 27        9.0               Cash flows from financing activities
# 28        9.0               Cash flows from financing activities
# 29        9.0               Cash flows from financing activities
# 30        9.0               Cash flows from financing activities
# 31        9.0               Cash flows from financing activities
# 32        9.0               Cash flows from financing activities
# 33        9.0               Cash flows from financing activities
# 34        9.0               Cash flows from financing activities
# 35       10.0                                                NaN
# 36       10.0                                                NaN
# 37       10.0                                                NaN
# 38       10.0                                                NaN
# 39       11.0   Supplemental disclosure of cash flow information
# 40       11.0   Supplemental disclosure of cash flow information
# 41        3.0  Adjustments to reconcile net income to net cas...
# 42        6.0               Cash flows from investing activities
# 43        6.0               Cash flows from investing activities
# 44        6.0               Cash flows from investing activities
# 45        6.0               Cash flows from investing activities
# 46        6.0               Cash flows from investing activities
# 47        8.0               Cash flows from financing activities
# 48        8.0               Cash flows from financing activities
# 49        1.0               Cash flows from operating activities
# 50        3.0  Adjustments to reconcile net income to net cas...
# 51        4.0        Changes in operating assets and liabilities
# 52        4.0        Changes in operating assets and liabilities
# 53        4.0        Changes in operating assets and liabilities
# 54        6.0               Cash flows from investing activities
# 55        7.0                                                NaN
# 56        8.0               Cash flows from financing activities
# 57       10.0   Supplemental disclosure of cash flow information
# 58       10.0   Supplemental disclosure of cash flow information
#
#                                                 label Oct. 30, 2021  \
# 0                                   net income (loss)           NaN
# 1                       depreciation and amortization           NaN
# 2                            share-based compensation           NaN
# 3                    operating lease, impairment loss           NaN
# 4                      other asset impairment charges           NaN
# 5               gain (loss) on extinguishment of debt           NaN
# 6                 amortization of debt issuance costs           NaN
# 7                            non-cash and other items           NaN
# 8              gain (loss) on disposition of business           NaN
# 9                               deferred income taxes           NaN
# 10                              merchandise inventory           NaN
# 11    other current assets and other long-term assets           NaN
# 12                                   accounts payable           NaN
# 13     accrued expenses and other current liabilities           NaN
# 14  income taxes payable, net of receivables and o...           NaN
# 15   lease incentives and other long-term liabilities           NaN
# 16        operating lease assets and liabilities, net           NaN
# 17  net cash provided by (used for) operating acti...           NaN
# 18                purchases of property and equipment           NaN
# 19         payments to acquire short-term investments           NaN
# 20  proceeds from sale, maturity and collection of...           NaN
# 21  payments for acquisition activity, net of cash...           NaN
# 22             net cash paid for divestiture activity           NaN
# 23                                              other           NaN
# 24  net cash provided by (used for) investing acti...           NaN
# 25                      proceeds from lines of credit           NaN
# 26  proceeds from issuances under share-based comp...           NaN
# 27  withholding tax payments related to vesting of...           NaN
# 28                        repurchases of common stock           NaN
# 29                                cash dividends paid           NaN
# 30           proceeds from issuance of long-term debt           NaN
# 31                        payments to extinguish debt           NaN
# 32                   payments for debt issuance costs           NaN
# 33                      repayments of lines of credit           NaN
# 34  net cash provided by (used for) financing acti...           NaN
# 35  effect of exchange rate on cash, cash equivale...           NaN
# 36  cash, cash equivalents, restricted cash and re...           NaN
# 37  cash, cash equivalents, restricted cash and re...           NaN
# 38  cash, cash equivalents, restricted cash and re...           NaN
# 39  interest paid, excluding capitalized interest,...           NaN
# 40  cash paid for income taxes during the period, ...           NaN
# 41  gain (loss) on disposition of property plant e...           NaN
# 42                    proceeds from sale of buildings           NaN
# 43  payments to acquire businesses, net of cash ac...           NaN
# 44                      payments to acquire buildings           NaN
# 45                                              other           NaN
# 46  net cash provided by (used for) investing acti...           NaN
# 47                       repayments of long-term debt           NaN
# 48                    payments of debt issuance costs           NaN
# 49                                         net income           NaN
# 50                   amortization of lease incentives           NaN
# 51  income taxes payable, net of prepaid and other...           NaN
# 52         changeoperatingleaseassetandliabilitiesnet           NaN
# 53          net cash provided by operating activities           NaN
# 54             net cash used for investing activities           NaN
# 55                      payments to acquire buildings           NaN
# 56             net cash used for financing activities           NaN
# 57           cash paid for interest during the period           NaN
# 58                          operating lease, payments           NaN
#
#    Oct. 31, 2020 Nov. 02, 2019 May 04, 2019 May 05, 2018
# 0            NaN           NaN          NaN          NaN
# 1            NaN           NaN          NaN          NaN
# 2            NaN           NaN          NaN          NaN
# 3            NaN           NaN          NaN          NaN
# 4            NaN           NaN          NaN          NaN
# 5            NaN           NaN          NaN          NaN
# 6            NaN           NaN          NaN          NaN
# 7            NaN           NaN          NaN          NaN
# 8            NaN           NaN          NaN          NaN
# 9            NaN           NaN          NaN          NaN
# 10           NaN           NaN          NaN          NaN
# 11           NaN           NaN          NaN          NaN
# 12           NaN           NaN          NaN          NaN
# 13           NaN           NaN          NaN          NaN
# 14           NaN           NaN          NaN          NaN
# 15           NaN           NaN          NaN          NaN
# 16           NaN           NaN          NaN          NaN
# 17           NaN           NaN          NaN          NaN
# 18           NaN           NaN          NaN          NaN
# 19           NaN           NaN          NaN          NaN
# 20           NaN           NaN          NaN          NaN
# 21           NaN           NaN          NaN          NaN
# 22           NaN           NaN          NaN          NaN
# 23           NaN           NaN          NaN          NaN
# 24           NaN           NaN          NaN          NaN
# 25           NaN           NaN          NaN          NaN
# 26           NaN           NaN          NaN          NaN
# 27           NaN           NaN          NaN          NaN
# 28           NaN           NaN          NaN          NaN
# 29           NaN           NaN          NaN          NaN
# 30           NaN           NaN          NaN          NaN
# 31           NaN           NaN          NaN          NaN
# 32           NaN           NaN          NaN          NaN
# 33           NaN           NaN          NaN          NaN
# 34           NaN           NaN          NaN          NaN
# 35           NaN           NaN          NaN          NaN
# 36           NaN           NaN          NaN          NaN
# 37           NaN           NaN          NaN          NaN
# 38           NaN           NaN          NaN          NaN
# 39           NaN           NaN          NaN          NaN
# 40           NaN           NaN          NaN          NaN
# 41           NaN           NaN          NaN          NaN
# 42           NaN           NaN          NaN          NaN
# 43           NaN           NaN          NaN          NaN
# 44           NaN           NaN          NaN          NaN
# 45           NaN           NaN          NaN          NaN
# 46           NaN           NaN          NaN          NaN
# 47           NaN           NaN          NaN          NaN
# 48           NaN           NaN          NaN          NaN
# 49           NaN           NaN          NaN          NaN
# 50           NaN           NaN          NaN          NaN
# 51           NaN           NaN          NaN          NaN
# 52           NaN           NaN          NaN          NaN
# 53           NaN           NaN          NaN          NaN
# 54           NaN           NaN          NaN          NaN
# 55           NaN           NaN          NaN          NaN
# 56           NaN           NaN          NaN          NaN
# 57           NaN           NaN          NaN          NaN
# 58           NaN           NaN          NaN          NaN
# q2 2021.xlsx
#     num_title                                              title  \
# 0         1.0               Cash flows from operating activities
# 1         3.0  Adjustments to reconcile net income to net cas...
# 2         3.0  Adjustments to reconcile net income to net cas...
# 3         3.0  Adjustments to reconcile net income to net cas...
# 4         3.0  Adjustments to reconcile net income to net cas...
# 5         3.0  Adjustments to reconcile net income to net cas...
# 6         3.0  Adjustments to reconcile net income to net cas...
# 7         3.0  Adjustments to reconcile net income to net cas...
# 8         3.0  Adjustments to reconcile net income to net cas...
# 9         3.0  Adjustments to reconcile net income to net cas...
# 10        4.0        Changes in operating assets and liabilities
# 11        4.0        Changes in operating assets and liabilities
# 12        4.0        Changes in operating assets and liabilities
# 13        4.0        Changes in operating assets and liabilities
# 14        4.0        Changes in operating assets and liabilities
# 15        4.0        Changes in operating assets and liabilities
# 16        4.0        Changes in operating assets and liabilities
# 17        4.0        Changes in operating assets and liabilities
# 18        6.0               Cash flows from investing activities
# 19        6.0               Cash flows from investing activities
# 20        6.0               Cash flows from investing activities
# 21        6.0               Cash flows from investing activities
# 22        6.0               Cash flows from investing activities
# 23        7.0                                                NaN
# 24        7.0                                                NaN
# 25        9.0               Cash flows from financing activities
# 26        9.0               Cash flows from financing activities
# 27        9.0               Cash flows from financing activities
# 28        9.0               Cash flows from financing activities
# 29        9.0               Cash flows from financing activities
# 30        9.0               Cash flows from financing activities
# 31        9.0               Cash flows from financing activities
# 32        9.0               Cash flows from financing activities
# 33        9.0               Cash flows from financing activities
# 34        9.0               Cash flows from financing activities
# 35       10.0                                                NaN
# 36       10.0                                                NaN
# 37       10.0                                                NaN
# 38       10.0                                                NaN
# 39       11.0   Supplemental disclosure of cash flow information
# 40       11.0   Supplemental disclosure of cash flow information
# 41        3.0  Adjustments to reconcile net income to net cas...
# 42        6.0               Cash flows from investing activities
# 43        6.0               Cash flows from investing activities
# 44        6.0               Cash flows from investing activities
# 45        6.0               Cash flows from investing activities
# 46        6.0               Cash flows from investing activities
# 47        8.0               Cash flows from financing activities
# 48        8.0               Cash flows from financing activities
# 49        1.0               Cash flows from operating activities
# 50        3.0  Adjustments to reconcile net income to net cas...
# 51        4.0        Changes in operating assets and liabilities
# 52        4.0        Changes in operating assets and liabilities
# 53        4.0        Changes in operating assets and liabilities
# 54        6.0               Cash flows from investing activities
# 55        7.0                                                NaN
# 56        8.0               Cash flows from financing activities
# 57       10.0   Supplemental disclosure of cash flow information
# 58       10.0   Supplemental disclosure of cash flow information
#
#                                                 label Oct. 30, 2021  \
# 0                                   net income (loss)           NaN
# 1                       depreciation and amortization           NaN
# 2                            share-based compensation           NaN
# 3                    operating lease, impairment loss           NaN
# 4                      other asset impairment charges           NaN
# 5               gain (loss) on extinguishment of debt           NaN
# 6                 amortization of debt issuance costs           NaN
# 7                            non-cash and other items           NaN
# 8              gain (loss) on disposition of business           NaN
# 9                               deferred income taxes           NaN
# 10                              merchandise inventory           NaN
# 11    other current assets and other long-term assets           NaN
# 12                                   accounts payable           NaN
# 13     accrued expenses and other current liabilities           NaN
# 14  income taxes payable, net of receivables and o...           NaN
# 15   lease incentives and other long-term liabilities           NaN
# 16        operating lease assets and liabilities, net           NaN
# 17  net cash provided by (used for) operating acti...           NaN
# 18                purchases of property and equipment           NaN
# 19         payments to acquire short-term investments           NaN
# 20  proceeds from sale, maturity and collection of...           NaN
# 21  payments for acquisition activity, net of cash...           NaN
# 22             net cash paid for divestiture activity           NaN
# 23                                              other           NaN
# 24  net cash provided by (used for) investing acti...           NaN
# 25                      proceeds from lines of credit           NaN
# 26  proceeds from issuances under share-based comp...           NaN
# 27  withholding tax payments related to vesting of...           NaN
# 28                        repurchases of common stock           NaN
# 29                                cash dividends paid           NaN
# 30           proceeds from issuance of long-term debt           NaN
# 31                        payments to extinguish debt           NaN
# 32                   payments for debt issuance costs           NaN
# 33                      repayments of lines of credit           NaN
# 34  net cash provided by (used for) financing acti...           NaN
# 35  effect of exchange rate on cash, cash equivale...           NaN
# 36  cash, cash equivalents, restricted cash and re...           NaN
# 37  cash, cash equivalents, restricted cash and re...           NaN
# 38  cash, cash equivalents, restricted cash and re...           NaN
# 39  interest paid, excluding capitalized interest,...           NaN
# 40  cash paid for income taxes during the period, ...           NaN
# 41  gain (loss) on disposition of property plant e...           NaN
# 42                    proceeds from sale of buildings           NaN
# 43  payments to acquire businesses, net of cash ac...           NaN
# 44                      payments to acquire buildings           NaN
# 45                                              other           NaN
# 46  net cash provided by (used for) investing acti...           NaN
# 47                       repayments of long-term debt           NaN
# 48                    payments of debt issuance costs           NaN
# 49                                         net income           NaN
# 50                   amortization of lease incentives           NaN
# 51  income taxes payable, net of prepaid and other...           NaN
# 52         changeoperatingleaseassetandliabilitiesnet           NaN
# 53          net cash provided by operating activities           NaN
# 54             net cash used for investing activities           NaN
# 55                      payments to acquire buildings           NaN
# 56             net cash used for financing activities           NaN
# 57           cash paid for interest during the period           NaN
# 58                          operating lease, payments           NaN
#
#    Oct. 31, 2020 Nov. 02, 2019 May 04, 2019 May 05, 2018 Jul. 31, 2021  \
# 0            NaN           NaN          NaN          NaN           NaN
# 1            NaN           NaN          NaN          NaN           NaN
# 2            NaN           NaN          NaN          NaN           NaN
# 3            NaN           NaN          NaN          NaN           NaN
# 4            NaN           NaN          NaN          NaN           NaN
# 5            NaN           NaN          NaN          NaN           NaN
# 6            NaN           NaN          NaN          NaN           NaN
# 7            NaN           NaN          NaN          NaN           NaN
# 8            NaN           NaN          NaN          NaN           NaN
# 9            NaN           NaN          NaN          NaN           NaN
# 10           NaN           NaN          NaN          NaN           NaN
# 11           NaN           NaN          NaN          NaN           NaN
# 12           NaN           NaN          NaN          NaN           NaN
# 13           NaN           NaN          NaN          NaN           NaN
# 14           NaN           NaN          NaN          NaN           NaN
# 15           NaN           NaN          NaN          NaN           NaN
# 16           NaN           NaN          NaN          NaN           NaN
# 17           NaN           NaN          NaN          NaN           NaN
# 18           NaN           NaN          NaN          NaN           NaN
# 19           NaN           NaN          NaN          NaN           NaN
# 20           NaN           NaN          NaN          NaN           NaN
# 21           NaN           NaN          NaN          NaN           NaN
# 22           NaN           NaN          NaN          NaN           NaN
# 23           NaN           NaN          NaN          NaN           NaN
# 24           NaN           NaN          NaN          NaN           NaN
# 25           NaN           NaN          NaN          NaN           NaN
# 26           NaN           NaN          NaN          NaN           NaN
# 27           NaN           NaN          NaN          NaN           NaN
# 28           NaN           NaN          NaN          NaN           NaN
# 29           NaN           NaN          NaN          NaN           NaN
# 30           NaN           NaN          NaN          NaN           NaN
# 31           NaN           NaN          NaN          NaN           NaN
# 32           NaN           NaN          NaN          NaN           NaN
# 33           NaN           NaN          NaN          NaN           NaN
# 34           NaN           NaN          NaN          NaN           NaN
# 35           NaN           NaN          NaN          NaN           NaN
# 36           NaN           NaN          NaN          NaN           NaN
# 37           NaN           NaN          NaN          NaN           NaN
# 38           NaN           NaN          NaN          NaN           NaN
# 39           NaN           NaN          NaN          NaN           NaN
# 40           NaN           NaN          NaN          NaN           NaN
# 41           NaN           NaN          NaN          NaN           NaN
# 42           NaN           NaN          NaN          NaN           NaN
# 43           NaN           NaN          NaN          NaN           NaN
# 44           NaN           NaN          NaN          NaN           NaN
# 45           NaN           NaN          NaN          NaN           NaN
# 46           NaN           NaN          NaN          NaN           NaN
# 47           NaN           NaN          NaN          NaN           NaN
# 48           NaN           NaN          NaN          NaN           NaN
# 49           NaN           NaN          NaN          NaN           NaN
# 50           NaN           NaN          NaN          NaN           NaN
# 51           NaN           NaN          NaN          NaN           NaN
# 52           NaN           NaN          NaN          NaN           NaN
# 53           NaN           NaN          NaN          NaN           NaN
# 54           NaN           NaN          NaN          NaN           NaN
# 55           NaN           NaN          NaN          NaN           NaN
# 56           NaN           NaN          NaN          NaN           NaN
# 57           NaN           NaN          NaN          NaN           NaN
# 58           NaN           NaN          NaN          NaN           NaN
#
#    Aug. 01, 2020
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# 5            NaN
# 6            NaN
# 7            NaN
# 8            NaN
# 9            NaN
# 10           NaN
# 11           NaN
# 12           NaN
# 13           NaN
# 14           NaN
# 15           NaN
# 16           NaN
# 17           NaN
# 18           NaN
# 19           NaN
# 20           NaN
# 21           NaN
# 22           NaN
# 23           NaN
# 24           NaN
# 25           NaN
# 26           NaN
# 27           NaN
# 28           NaN
# 29           NaN
# 30           NaN
# 31           NaN
# 32           NaN
# 33           NaN
# 34           NaN
# 35           NaN
# 36           NaN
# 37           NaN
# 38           NaN
# 39           NaN
# 40           NaN
# 41           NaN
# 42           NaN
# 43           NaN
# 44           NaN
# 45           NaN
# 46           NaN
# 47           NaN
# 48           NaN
# 49           NaN
# 50           NaN
# 51           NaN
# 52           NaN
# 53           NaN
# 54           NaN
# 55           NaN
# 56           NaN
# 57           NaN
# 58           NaN
# q2 2020.xlsx
#     num_title                                              title  \
# 0         1.0               Cash flows from operating activities
# 1         3.0  Adjustments to reconcile net income to net cas...
# 2         3.0  Adjustments to reconcile net income to net cas...
# 3         3.0  Adjustments to reconcile net income to net cas...
# 4         3.0  Adjustments to reconcile net income to net cas...
# 5         3.0  Adjustments to reconcile net income to net cas...
# 6         3.0  Adjustments to reconcile net income to net cas...
# 7         3.0  Adjustments to reconcile net income to net cas...
# 8         3.0  Adjustments to reconcile net income to net cas...
# 9         3.0  Adjustments to reconcile net income to net cas...
# 10        4.0        Changes in operating assets and liabilities
# 11        4.0        Changes in operating assets and liabilities
# 12        4.0        Changes in operating assets and liabilities
# 13        4.0        Changes in operating assets and liabilities
# 14        4.0        Changes in operating assets and liabilities
# 15        4.0        Changes in operating assets and liabilities
# 16        4.0        Changes in operating assets and liabilities
# 17        4.0        Changes in operating assets and liabilities
# 18        6.0               Cash flows from investing activities
# 19        6.0               Cash flows from investing activities
# 20        6.0               Cash flows from investing activities
# 21        6.0               Cash flows from investing activities
# 22        6.0               Cash flows from investing activities
# 23        7.0                                                NaN
# 24        7.0                                                NaN
# 25        9.0               Cash flows from financing activities
# 26        9.0               Cash flows from financing activities
# 27        9.0               Cash flows from financing activities
# 28        9.0               Cash flows from financing activities
# 29        9.0               Cash flows from financing activities
# 30        9.0               Cash flows from financing activities
# 31        9.0               Cash flows from financing activities
# 32        9.0               Cash flows from financing activities
# 33        9.0               Cash flows from financing activities
# 34        9.0               Cash flows from financing activities
# 35       10.0                                                NaN
# 36       10.0                                                NaN
# 37       10.0                                                NaN
# 38       10.0                                                NaN
# 39       11.0   Supplemental disclosure of cash flow information
# 40       11.0   Supplemental disclosure of cash flow information
# 41        3.0  Adjustments to reconcile net income to net cas...
# 42        6.0               Cash flows from investing activities
# 43        6.0               Cash flows from investing activities
# 44        6.0               Cash flows from investing activities
# 45        6.0               Cash flows from investing activities
# 46        6.0               Cash flows from investing activities
# 47        8.0               Cash flows from financing activities
# 48        8.0               Cash flows from financing activities
# 49        1.0               Cash flows from operating activities
# 50        3.0  Adjustments to reconcile net income to net cas...
# 51        4.0        Changes in operating assets and liabilities
# 52        4.0        Changes in operating assets and liabilities
# 53        4.0        Changes in operating assets and liabilities
# 54        6.0               Cash flows from investing activities
# 55        7.0                                                NaN
# 56        8.0               Cash flows from financing activities
# 57       10.0   Supplemental disclosure of cash flow information
# 58       10.0   Supplemental disclosure of cash flow information
#
#                                                 label Oct. 30, 2021  \
# 0                                   net income (loss)           NaN
# 1                       depreciation and amortization           NaN
# 2                            share-based compensation           NaN
# 3                    operating lease, impairment loss           NaN
# 4                      other asset impairment charges           NaN
# 5               gain (loss) on extinguishment of debt           NaN
# 6                 amortization of debt issuance costs           NaN
# 7                            non-cash and other items           NaN
# 8              gain (loss) on disposition of business           NaN
# 9                               deferred income taxes           NaN
# 10                              merchandise inventory           NaN
# 11    other current assets and other long-term assets           NaN
# 12                                   accounts payable           NaN
# 13     accrued expenses and other current liabilities           NaN
# 14  income taxes payable, net of receivables and o...           NaN
# 15   lease incentives and other long-term liabilities           NaN
# 16        operating lease assets and liabilities, net           NaN
# 17  net cash provided by (used for) operating acti...           NaN
# 18                purchases of property and equipment           NaN
# 19         payments to acquire short-term investments           NaN
# 20  proceeds from sale, maturity and collection of...           NaN
# 21  payments for acquisition activity, net of cash...           NaN
# 22             net cash paid for divestiture activity           NaN
# 23                                              other           NaN
# 24  net cash provided by (used for) investing acti...           NaN
# 25                      proceeds from lines of credit           NaN
# 26  proceeds from issuances under share-based comp...           NaN
# 27  withholding tax payments related to vesting of...           NaN
# 28                        repurchases of common stock           NaN
# 29                                cash dividends paid           NaN
# 30           proceeds from issuance of long-term debt           NaN
# 31                        payments to extinguish debt           NaN
# 32                   payments for debt issuance costs           NaN
# 33                      repayments of lines of credit           NaN
# 34  net cash provided by (used for) financing acti...           NaN
# 35  effect of exchange rate on cash, cash equivale...           NaN
# 36  cash, cash equivalents, restricted cash and re...           NaN
# 37  cash, cash equivalents, restricted cash and re...           NaN
# ...
# 92  purchases of property and equipment not yet pa...           NaN
# 93          cash paid for operating lease liabilities           NaN
#
#    Oct. 31, 2020 Nov. 02, 2019 May 04, 2019 May 05, 2018 Jul. 31, 2021  \
# 0            NaN           NaN          NaN          NaN           NaN
# 1            NaN           NaN          NaN          NaN           NaN
# 2            NaN           NaN          NaN          NaN           NaN
# 3            NaN           NaN          NaN          NaN           NaN
# 4            NaN           NaN          NaN          NaN           NaN
# ..           ...           ...          ...          ...           ...
# 89           NaN           NaN          NaN          NaN           NaN
# 90           NaN           NaN          NaN          NaN           NaN
# 91           NaN           NaN          NaN          NaN           NaN
# 92           NaN           NaN          NaN          NaN           NaN
# 93           NaN           NaN          NaN          NaN           NaN
#
#    Aug. 01, 2020 Aug. 03, 2019 Feb. 01, 2020 Feb. 02, 2019 Feb. 03, 2018  \
# 0            NaN           NaN           NaN           NaN           NaN
# 1            NaN           NaN           NaN           NaN           NaN
# 2            NaN           NaN           NaN           NaN           NaN
# 3            NaN           NaN           NaN           NaN           NaN
# 4            NaN           NaN           NaN           NaN           NaN
# ..           ...           ...           ...           ...           ...
# 89           NaN           NaN           NaN           NaN           NaN
# 90           NaN           NaN           NaN           NaN           NaN
# 91           NaN           NaN           NaN           NaN           NaN
# 92           NaN           NaN           NaN           NaN           NaN
# 93           NaN           NaN           NaN           NaN           NaN
#
#    Jan. 28, 2017 May 01, 2021 May 02, 2020 Aug. 04, 2018 Jan. 29, 2022  \
# 0            NaN          NaN          NaN           NaN           NaN
# 1            NaN          NaN          NaN           NaN           NaN
# 2            NaN          NaN          NaN           NaN           NaN
# 3            NaN          NaN          NaN           NaN           NaN
# 4            NaN          NaN          NaN           NaN           NaN
# ..           ...          ...          ...           ...           ...
# 89           NaN          NaN          NaN           NaN           NaN
# 90           NaN          NaN          NaN           NaN           NaN
# 91           NaN          NaN          NaN           NaN           NaN
# 92           NaN          NaN          NaN           NaN           NaN
# 93           NaN          NaN          NaN           NaN           NaN
#
#    Jan. 30, 2021
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ..           ...
# 89           NaN
# 90           NaN
# 91           NaN
# 92           NaN
# 93           NaN
#
# [94 rows x 20 columns]
# q3 2019.xlsx
#     num_title                                              title  \
# 0         1.0               Cash flows from operating activities
# 1         3.0  Adjustments to reconcile net income to net cas...
# 2         3.0  Adjustments to reconcile net income to net cas...
# 3         3.0  Adjustments to reconcile net income to net cas...
# 4         3.0  Adjustments to reconcile net income to net cas...
# ..        ...                                                ...
# 89        9.0               Cash flows from financing activities
# 90       10.0                                                NaN
# 91       11.0                                                NaN
# 92       11.0                                                NaN
# 93       12.0   Supplemental disclosure of cash flow information
#
#                                                 label Oct. 30, 2021  \
# 0                                   net income (loss)           NaN
# 1                       depreciation and amortization           NaN
# 2                            share-based compensation           NaN
# 3                    operating lease, impairment loss           NaN
# 4                      other asset impairment charges           NaN
# ..                                                ...           ...
# 89             payments for revolving credit facility           NaN
# 90  effect of foreign exchange rate fluctuations o...           NaN
# 91  cash flow non cash investing disclosure [abstr...           NaN
# 92  purchases of property and equipment not yet pa...           NaN
# 93          cash paid for operating lease liabilities           NaN
#
#    Oct. 31, 2020 Nov. 02, 2019 May 04, 2019 May 05, 2018 Jul. 31, 2021  \
# 0            NaN           NaN          NaN          NaN           NaN
# 1            NaN           NaN          NaN          NaN           NaN
# 2            NaN           NaN          NaN          NaN           NaN
# 3            NaN           NaN          NaN          NaN           NaN
# 4            NaN           NaN          NaN          NaN           NaN
# ..           ...           ...          ...          ...           ...
# 89           NaN           NaN          NaN          NaN           NaN
# 90           NaN           NaN          NaN          NaN           NaN
# 91           NaN           NaN          NaN          NaN           NaN
# 92           NaN           NaN          NaN          NaN           NaN
# 93           NaN           NaN          NaN          NaN           NaN
#
#    Aug. 01, 2020  ... Feb. 01, 2020 Feb. 02, 2019 Feb. 03, 2018 Jan. 28, 2017  \
# 0            NaN  ...           NaN           NaN           NaN           NaN
# 1            NaN  ...           NaN           NaN           NaN           NaN
# 2            NaN  ...           NaN           NaN           NaN           NaN
# 3            NaN  ...           NaN           NaN           NaN           NaN
# 4            NaN  ...           NaN           NaN           NaN           NaN
# ..           ...  ...           ...           ...           ...           ...
# 89           NaN  ...           NaN           NaN           NaN           NaN
# 90           NaN  ...           NaN           NaN           NaN           NaN
# 91           NaN  ...           NaN           NaN           NaN           NaN
# 92           NaN  ...           NaN           NaN           NaN           NaN
# 93           NaN  ...           NaN           NaN           NaN           NaN
#
#    May 01, 2021 May 02, 2020 Aug. 04, 2018 Jan. 29, 2022 Jan. 30, 2021  \
# 0           NaN          NaN           NaN           NaN           NaN
# 1           NaN          NaN           NaN           NaN           NaN
# 2           NaN          NaN           NaN           NaN           NaN
# 3           NaN          NaN           NaN           NaN           NaN
# 4           NaN          NaN           NaN           NaN           NaN
# ..          ...          ...           ...           ...           ...
# 89          NaN          NaN           NaN           NaN           NaN
# 90          NaN          NaN           NaN           NaN           NaN
# 91          NaN          NaN           NaN           NaN           NaN
# 92          NaN          NaN           NaN           NaN           NaN
# 93          NaN          NaN           NaN           NaN           NaN
#
#    Nov. 03, 2018
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ..           ...
# 89           NaN
# 90           NaN
# 91           NaN
# 92           NaN
# 93           NaN
#
# [94 rows x 21 columns]
# 10k 2021 (2022).xlsx
#      num_title                                              title  \
# 0          1.0               Cash flows from operating activities
# 1          3.0  Adjustments to reconcile net income to net cas...
# 2          3.0  Adjustments to reconcile net income to net cas...
# 3          3.0  Adjustments to reconcile net income to net cas...
# 4          3.0  Adjustments to reconcile net income to net cas...
# ..         ...                                                ...
# 98         8.0               Cash flows from financing activities
# 99         8.0               Cash flows from financing activities
# 100       10.0                                                NaN
# 101       11.0   Supplemental disclosure of cash flow information
# 102       11.0   Supplemental disclosure of cash flow information
#
#                                                  label Oct. 30, 2021  \
# 0                                    net income (loss)           NaN
# 1                        depreciation and amortization           NaN
# 2                             share-based compensation           NaN
# 3                     operating lease, impairment loss           NaN
# 4                       other asset impairment charges           NaN
# ..                                                 ...           ...
# 98                               payments of dividends           NaN
# 99   net cash provided by (used in) financing activ...           NaN
# 100     capital expenditures incurred but not yet paid           NaN
# 101  interest paid, including capitalized interest,...           NaN
# 102                                  income taxes paid           NaN
#
#     Oct. 31, 2020 Nov. 02, 2019 May 04, 2019 May 05, 2018 Jul. 31, 2021  \
# 0             NaN           NaN          NaN          NaN           NaN
# 1             NaN           NaN          NaN          NaN           NaN
# 2             NaN           NaN          NaN          NaN           NaN
# 3             NaN           NaN          NaN          NaN           NaN
# 4             NaN           NaN          NaN          NaN           NaN
# ..            ...           ...          ...          ...           ...
# 98            NaN           NaN          NaN          NaN           NaN
# 99            NaN           NaN          NaN          NaN           NaN
# 100           NaN           NaN          NaN          NaN           NaN
# 101           NaN           NaN          NaN          NaN           NaN
# 102           NaN           NaN          NaN          NaN           NaN
#
#     Aug. 01, 2020  ... Feb. 01, 2020 Feb. 02, 2019 Feb. 03, 2018  \
# 0             NaN  ...           NaN           NaN           NaN
# 1             NaN  ...           NaN           NaN           NaN
# 2             NaN  ...           NaN           NaN           NaN
# 3             NaN  ...           NaN           NaN           NaN
# 4             NaN  ...           NaN           NaN           NaN
# ..            ...  ...           ...           ...           ...
# 98            NaN  ...           NaN           NaN           NaN
# 99            NaN  ...           NaN           NaN           NaN
# 100           NaN  ...           NaN           NaN           NaN
# 101           NaN  ...           NaN           NaN           NaN
# 102           NaN  ...           NaN           NaN           NaN
#
#     Jan. 28, 2017 May 01, 2021 May 02, 2020 Aug. 04, 2018 Jan. 29, 2022  \
# 0             NaN          NaN          NaN           NaN           NaN
# 1             NaN          NaN          NaN           NaN           NaN
# 2             NaN          NaN          NaN           NaN           NaN
# 3             NaN          NaN          NaN           NaN           NaN
# 4             NaN          NaN          NaN           NaN           NaN
# ..            ...          ...          ...           ...           ...
# 98            NaN          NaN          NaN           NaN           NaN
# 99            NaN          NaN          NaN           NaN           NaN
# 100           NaN          NaN          NaN           NaN           NaN
# 101           NaN          NaN          NaN           NaN           NaN
# 102           NaN          NaN          NaN           NaN           NaN
#
#     Jan. 30, 2021 Nov. 03, 2018
# 0             NaN           NaN
# 1             NaN           NaN
# 2             NaN           NaN
# 3             NaN           NaN
# 4             NaN           NaN
# ..            ...           ...
# 98            NaN           NaN
# 99            NaN           NaN
# 100           NaN           NaN
# 101           NaN           NaN
# 102           NaN           NaN
#
# [103 rows x 21 columns]
#      num_label                                              title  \
# 0            0               Cash flows from operating activities
# 1            1               Cash flows from operating activities
# 2            2  Adjustments to reconcile net income to net cas...
# 3            3  Adjustments to reconcile net income to net cas...
# 4            4  Adjustments to reconcile net income to net cas...
# ..         ...                                                ...
# 98          98   Supplemental disclosure of cash flow information
# 99          99   Supplemental disclosure of cash flow information
# 100        100   Supplemental disclosure of cash flow information
# 101        101   Supplemental disclosure of cash flow information
# 102        102   Supplemental disclosure of cash flow information
#
#                                                  label  num_title Q4 2017  \
# 0                                    net income (loss)        1.0     NaN
# 1                                           net income        1.0     NaN
# 2                        depreciation and amortization        3.0     NaN
# 3                             share-based compensation        3.0     NaN
# 4                     operating lease, impairment loss        3.0     NaN
# ..                                                 ...        ...     ...
# 98                                   income taxes paid       11.0     NaN
# 99   cash paid for income taxes during the period, ...       12.0     NaN
# 100           cash paid for interest during the period       12.0     NaN
# 101                          operating lease, payments       12.0     NaN
# 102          cash paid for operating lease liabilities       12.0     NaN
#
#     Q4 2018 Q1 2019 Q2 2019 Q3 2019 Q4 2019  ... Q3 2020 Q4 2020 Q1 2021  \
# 0       NaN     NaN     NaN     NaN     NaN  ...     NaN     NaN     NaN
# 1       NaN     NaN     NaN     NaN     NaN  ...     NaN     NaN     NaN
# 2       NaN     NaN     NaN     NaN     NaN  ...     NaN     NaN     NaN
# 3       NaN     NaN     NaN     NaN     NaN  ...     NaN     NaN     NaN
# 4       NaN     NaN     NaN     NaN     NaN  ...     NaN     NaN     NaN
# ..      ...     ...     ...     ...     ...  ...     ...     ...     ...
# 98      NaN     NaN     NaN     NaN     NaN  ...     NaN     NaN     NaN
# 99      NaN     NaN     NaN     NaN     NaN  ...     NaN     NaN     NaN
# 100     NaN     NaN     NaN     NaN     NaN  ...     NaN     NaN     NaN
# 101     NaN     NaN     NaN     NaN     NaN  ...     NaN     NaN     NaN
# 102     NaN     NaN     NaN     NaN     NaN  ...     NaN     NaN     NaN
#
#     Q2 2021 Q3 2021 Q4 2021 Q1 2022 Q2 2022 Q3 2022 Q4 2022
# 0       NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1       NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2       NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 3       NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4       NaN     NaN     NaN     NaN     NaN     NaN     NaN
# ..      ...     ...     ...     ...     ...     ...     ...
# 98      NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 99      NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 100     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 101     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 102     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
# [103 rows x 22 columns]

# %%
cols = finalCashFlow.columns[4:]
groupby = {x:"sum" for x in cols}
groupby.update({"label":"first","num_label":"min","num_title":"min"})

# %%
finalCashFlow[cols] = finalCashFlow[cols].fillna(0).astype('int32')

# %%
labels = [x.replace("Gain","Loss") for x in finalCashFlow.label]
labels = [re.sub("\([\w\W]+\)","",x).replace("  "," ").strip() for x in labels]

finalCashFlow["new_label"] = labels
finalCashFlow = finalCashFlow.groupby(["title","new_label"]).aggregate(groupby).reset_index()
finalCashFlow = finalCashFlow.sort_values(["num_title","num_label"])


finalCashFlow
# Out:
#                                                 title  \
# 63               Cash flows from operating activities
# 4   Adjustments to reconcile net income to net cas...
# 22  Adjustments to reconcile net income to net cas...
# 20  Adjustments to reconcile net income to net cas...
# 21  Adjustments to reconcile net income to net cas...
# ..                                                ...
# 79   Supplemental disclosure of cash flow information
# 76   Supplemental disclosure of cash flow information
# 77   Supplemental disclosure of cash flow information
# 82   Supplemental disclosure of cash flow information
# 78   Supplemental disclosure of cash flow information
#
#                                             new_label  Q4 2017  Q4 2018  \
# 63                                         net income        0        0
# 4                       depreciation and amortization        0        0
# 22                           share-based compensation        0        0
# 20                   operating lease, impairment loss        0        0
# 21                     other asset impairment charges        0        0
# ..                                                ...      ...      ...
# 79                                  income taxes paid        0        0
# 76  cash paid for income taxes during the period, ...        0        0
# 77           cash paid for interest during the period        0        0
# 82                          operating lease, payments        0        0
# 78          cash paid for operating lease liabilities        0        0
#
#     Q1 2019  Q2 2019  Q3 2019  Q4 2019  Q1 2020  Q2 2020  ...  Q2 2021  \
# 63        0        0        0        0        0        0  ...        0
# 4         0        0        0        0        0        0  ...        0
# 22        0        0        0        0        0        0  ...        0
# 20        0        0        0        0        0        0  ...        0
# 21        0        0        0        0        0        0  ...        0
# ..      ...      ...      ...      ...      ...      ...  ...      ...
# 79        0        0        0        0        0        0  ...        0
# 76        0        0        0        0        0        0  ...        0
# 77        0        0        0        0        0        0  ...        0
# 82        0        0        0        0        0        0  ...        0
# 78        0        0        0        0        0        0  ...        0
#
#     Q3 2021  Q4 2021  Q1 2022  Q2 2022  Q3 2022  Q4 2022  \
# 63        0        0        0        0        0        0
# 4         0        0        0        0        0        0
# 22        0        0        0        0        0        0
# 20        0        0        0        0        0        0
# 21        0        0        0        0        0        0
# ..      ...      ...      ...      ...      ...      ...
# 79        0        0        0        0        0        0
# 76        0        0        0        0        0        0
# 77        0        0        0        0        0        0
# 82        0        0        0        0        0        0
# 78        0        0        0        0        0        0
#
#                                                 label  num_label  num_title
# 63                                  net income (loss)          0        1.0
# 4                       depreciation and amortization          2        3.0
# 22                           share-based compensation          3        3.0
# 20                   operating lease, impairment loss          4        3.0
# 21                     other asset impairment charges          5        3.0
# ..                                                ...        ...        ...
# 79                                  income taxes paid         98       11.0
# 76  cash paid for income taxes during the period, ...         99       12.0
# 77           cash paid for interest during the period        100       12.0
# 82                          operating lease, payments        101       12.0
# 78          cash paid for operating lease liabilities        102       12.0
#
# [84 rows x 23 columns]

# %%
finalCashFlow.loc[~finalCashFlow[cols].isnull().all(axis=1)]
# Out:
#                                                 title  \
# 63               Cash flows from operating activities
# 4   Adjustments to reconcile net income to net cas...
# 22  Adjustments to reconcile net income to net cas...
# 20  Adjustments to reconcile net income to net cas...
# 21  Adjustments to reconcile net income to net cas...
# ..                                                ...
# 79   Supplemental disclosure of cash flow information
# 76   Supplemental disclosure of cash flow information
# 77   Supplemental disclosure of cash flow information
# 82   Supplemental disclosure of cash flow information
# 78   Supplemental disclosure of cash flow information
#
#                                             new_label Q4 2017 Q4 2018 Q1 2019  \
# 63                                         net income       0       0       0
# 4                       depreciation and amortization       0       0       0
# 22                           share-based compensation       0       0       0
# 20                   operating lease, impairment loss       0       0       0
# 21                     other asset impairment charges       0       0       0
# ..                                                ...     ...     ...     ...
# 79                                  income taxes paid       0       0       0
# 76  cash paid for income taxes during the period, ...       0       0       0
# 77           cash paid for interest during the period       0       0       0
# 82                          operating lease, payments       0       0       0
# 78          cash paid for operating lease liabilities       0       0       0
#
#    Q2 2019 Q3 2019 Q4 2019 Q1 2020 Q2 2020  ... Q2 2021 Q3 2021 Q4 2021  \
# 63       0       0       0       0       0  ...       0       0       0
# 4        0       0       0       0       0  ...       0       0       0
# 22       0       0       0       0       0  ...       0       0       0
# 20       0       0       0       0       0  ...       0       0       0
# 21       0       0       0       0       0  ...       0       0       0
# ..     ...     ...     ...     ...     ...  ...     ...     ...     ...
# 79       0       0       0       0       0  ...       0       0       0
# 76       0       0       0       0       0  ...       0       0       0
# 77       0       0       0       0       0  ...       0       0       0
# 82       0       0       0       0       0  ...       0       0       0
# 78       0       0       0       0       0  ...       0       0       0
#
#    Q1 2022 Q2 2022 Q3 2022 Q4 2022  \
# 63       0       0       0       0
# 4        0       0       0       0
# 22       0       0       0       0
# 20       0       0       0       0
# 21       0       0       0       0
# ..     ...     ...     ...     ...
# 79       0       0       0       0
# 76       0       0       0       0
# 77       0       0       0       0
# 82       0       0       0       0
# 78       0       0       0       0
#
#                                                 label num_label num_title
# 63                                  net income (loss)         0       1.0
# 4                       depreciation and amortization         2       3.0
# 22                           share-based compensation         3       3.0
# 20                   operating lease, impairment loss         4       3.0
# 21                     other asset impairment charges         5       3.0
# ..                                                ...       ...       ...
# 79                                  income taxes paid        98      11.0
# 76  cash paid for income taxes during the period, ...        99      12.0
# 77           cash paid for interest during the period       100      12.0
# 82                          operating lease, payments       101      12.0
# 78          cash paid for operating lease liabilities       102      12.0
#
# [84 rows x 23 columns]

# %%
finalCashFlow.to_csv("finalCashFlow.csv")

# %%
labels = [pos_tag(x.split()) for x in labels]

dict_pos = {"J": wordnet.ADJ,
                "NN": wordnet.NOUN,
                "VBD": wordnet.VERB,
                "VBZ": wordnet.VERB,
                "VBG": wordnet.VERB,
                "VBN": wordnet.VERB,
                "RB": wordnet.ADV,
                'IN':False}
def pos(x):
    return x.lower()[0]
labels = map(lambda sent: list(map(lambda x: [x[0].lower(),dict_pos.get(x[1],wordnet.NOUN)], sent)),labels)
labels = [[lemmatizer.lemmatize(word[0],pos=word[1]) for word in sent if word[1]] for sent in labels ]
[" ".join(sent) for sent in labels]
# Out:
# ['net income',
#  'net income',
#  'depreciation and amortization',
#  'share-based compensation',
#  'operate lease, impairment loss',
#  'other asset impairment charge',
#  'gain extinguishment debt',
#  'amortization debt issuance cost',
#  'non-cash and other item',
#  'gain disposition business',
#  'deferred income tax',
#  'gain disposition property plant equipment',
#  'amortization lease incentive',
#  'amortization lease incentive',
#  'gain disposition property plant equipment, exclude oil and gas property and timber property',
#  'tax benefit exercise stock option and vesting stock unit',
#  'excess tax benefit exercise stock option and vesting stock unit',
#  'goodwill, impairment loss',
#  'impairment operate lease asset',
#  'impairment store asset',
#  'impairment intangible asset',
#  'loss extinguishment debt',
#  'loss disposal property and equipment',
#  'loss divestiture activity',
#  'gain sale building',
#  'goodwill and intangible asset impairment',
#  'merchandise inventory',
#  'other current asset and other long-term asset',
#  'account payable',
#  'accrue expense and other current liability',
#  'income tax payable, net receivables and other tax-related item',
#  'lease incentive and other long-term liability',
#  'operate lease asset and liabilities, net',
#  'net cash provide operating activity',
#  'income tax payable, net prepaid and other tax-related item',
#  'changeoperatingleaseassetandliabilitiesnet',
#  'net cash provide operating activity',
#  'other long-term liability',
#  'purchase property and equipment',
#  'payment to acquire short-term investment',
#  'proceeds sale, maturity and collection short-term investment',
#  'payment acquisition activity, net cash acquire',
#  'net cash pay divestiture activity',
#  'other',
#  'net cash provide invest activity',
#  'proceeds sale building',
#  'payment to acquire businesses, net cash acquire',
#  'payment to acquire building',
#  'net cash use invest activity',
#  'sale and maturity short-term investment',
#  'insurance proceeds relate to loss property and equipment',
#  'purchase building',
#  'proceeds sale building',
#  'purchase short-term investment',
#  'proceeds sale and maturity short-term investment',
#  'payment to acquire property, plant, and equipment',
#  'net cash provide invest activity',
#  'proceeds line credit',
#  'proceeds issuance share-based compensation plan',
#  'withhold tax payment relate to vesting stock unit',
#  'repurchase common stock',
#  'cash dividend pay',
#  'proceeds issuance long-term debt',
#  'payment to extinguish debt',
#  'payment debt issuance cost',
#  'repayment line credit',
#  'net cash provide financing activity',
#  'effect exchange rate cash, cash equivalents, restrict cash and restricted cash equivalent',
#  'cash, cash equivalents, restrict cash and restricted cash equivalents, period increase , include exchange rate effect',
#  'cash, cash equivalents, restrict cash and restricted cash equivalent begin period',
#  'cash, cash equivalents, restrict cash and restricted cash equivalent end period',
#  'repayment long-term debt',
#  'payment debt issuance cost',
#  'net cash use financing activity',
#  'payment debt',
#  'other',
#  'effect exchange rate cash, cash equivalents, and restrict cash',
#  'net increase cash, cash equivalents, and restrict cash',
#  'cash, cash equivalents, and restricted cash begin period',
#  'cash, cash equivalents, and restrict cash end period',
#  'excess tax benefit exercise stock option and vesting stock unit',
#  'proceeds revolve credit facility',
#  'payment revolve credit facility',
#  'effect foreign exchange rate fluctuation cash, cash equivalents, and restrict cash',
#  'cash flow non cash invest disclosure [abstract]',
#  'purchase property and equipment not yet pay end period',
#  'payment repurchase common stock',
#  'payment dividend',
#  'net cash provide finance activities, total',
#  'capital expenditure incur but not yet pay',
#  'interest paid, exclude capitalize interest, operating activity',
#  'purchase property and equipment not yet pay end period',
#  'proceeds revolve credit facility',
#  'cash pay operating lease liability',
#  'interest paid, include capitalize interest, operating and investing activity',
#  'income tax pay',
#  'cash pay income tax the period, net refund',
#  'cash pay interest the period',
#  'operate lease, payment']

# %%
list(labels)
# Out:
# [[['net', 'n'], ['income', 'n'], ['(loss)', 'n']],
#  [['net', 'n'], ['income', 'n']],
#  [['depreciation', 'n'], ['and', 'n'], ['amortization', 'n']],
#  [['share-based', 'n'], ['compensation', 'n']],
#  [['operating', 'v'], ['lease,', 'n'], ['impairment', 'n'], ['loss', 'n']],
#  [['other', 'n'], ['asset', 'n'], ['impairment', 'n'], ['charges', 'n']],
#  [['loss', 'n'],
#   ['on', 'n'],
#   ['extinguishment', 'n'],
#   ['of', 'n'],
#   ['debt', 'n']],
#  [['amortization', 'n'],
#   ['of', 'n'],
#   ['debt', 'n'],
#   ['issuance', 'n'],
#   ['costs', 'n']],
#  [['non-cash', 'n'], ['and', 'n'], ['other', 'n'], ['items', 'n']],
#  [['loss', 'n'],
#   ['on', 'n'],
#   ['disposition', 'n'],
#   ['of', 'n'],
#   ['business', 'n']],
#  [['deferred', 'n'], ['income', 'n'], ['taxes', 'n']],
#  [['loss', 'n'],
#   ['on', 'n'],
#   ['disposition', 'n'],
#   ['of', 'n'],
#   ['property', 'n'],
#   ['plant', 'n'],
#   ['equipment', 'n']],
#  [['amortization', 'n'], ['of', 'n'], ['lease', 'n'], ['incentives', 'n']],
#  [['amortization', 'n'], ['lease', 'n'], ['incentives', 'n']],
#  [['loss', 'n'],
#   ['on', 'n'],
#   ['disposition', 'n'],
#   ['of', 'n'],
#   ['property', 'n'],
#   ['plant', 'n'],
#   ['equipment,', 'n'],
#   ['excluding', 'n'],
#   ['oil', 'n'],
#   ['and', 'n'],
#   ['gas', 'n'],
#   ['property', 'n'],
#   ['and', 'n'],
#   ['timber', 'n'],
#   ['property', 'n']],
#  [['tax', 'n'],
#   ['benefit', 'n'],
#   ['from', 'n'],
#   ['exercise', 'n'],
#   ['of', 'n'],
#   ['stock', 'n'],
#   ['options', 'n'],
#   ['and', 'n'],
#   ['vesting', 'n'],
#   ['of', 'n'],
#   ['stock', 'n'],
#   ['units', 'n']],
#  [['excess', 'n'],
#   ['tax', 'n'],
#   ['benefit', 'n'],
#   ['from', 'n'],
#   ['exercise', 'n'],
#   ['of', 'n'],
#   ['stock', 'n'],
#   ['options', 'n'],
#   ['and', 'n'],
#   ['vesting', 'n'],
#   ['of', 'n'],
#   ['stock', 'n'],
#   ['units', 'n']],
#  [['goodwill,', 'n'], ['impairment', 'n'], ['loss', 'n']],
#  [['depreciation', 'n'], ['and', 'n'], ['amortization', 'n']],
#  [['share-based', 'n'], ['compensation', 'n']],
#  [['impairment', 'n'],
#   ['of', 'n'],
#   ['operating', 'v'],
#   ['lease', 'n'],
#   ['assets', 'n']],
#  [['impairment', 'n'], ['of', 'n'], ['store', 'n'], ['assets', 'n']],
#  [['impairment', 'n'], ['of', 'n'], ['intangible', 'n'], ['asset', 'n']],
#  [['loss', 'n'],
#   ['on', 'n'],
#   ['extinguishment', 'n'],
#   ['of', 'n'],
#   ['debt', 'n']],
#  [['loss', 'n'],
#   ['on', 'n'],
#   ['disposal', 'n'],
#   ['of', 'n'],
#   ['property', 'n'],
#   ['and', 'n'],
#   ['equipment', 'n']],
#  [['amortization', 'n'],
#   ['of', 'n'],
#   ['debt', 'n'],
#   ['issuance', 'n'],
#   ['costs', 'n']],
#  [['non-cash', 'n'], ['and', 'n'], ['other', 'n'], ['items', 'n']],
#  [['loss', 'n'], ['on', 'n'], ['divestiture', 'n'], ['activity', 'n']],
#  [['loss', 'n'], ['on', 'n'], ['sale', 'n'], ['of', 'n'], ['building', 'n']],
#  [['deferred', 'n'], ['income', 'n'], ['taxes', 'n']],
#  [['goodwill', 'n'],
#   ['and', 'n'],
#   ['intangible', 'n'],
#   ['asset', 'n'],
#   ['impairment', 'n']],
#  [['merchandise', 'n'], ['inventory', 'n']],
#  [['other', 'n'],
#   ['current', 'n'],
#   ['assets', 'n'],
#   ['and', 'n'],
#   ['other', 'n'],
#   ['long-term', 'n'],
#   ['assets', 'n']],
#  [['accounts', 'n'], ['payable', 'n']],
#  [['accrued', 'v'],
#   ['expenses', 'n'],
#   ['and', 'n'],
#   ['other', 'n'],
#   ['current', 'n'],
#   ['liabilities', 'n']],
#  [['income', 'n'],
#   ['taxes', 'n'],
#   ['payable,', 'n'],
#   ['net', 'n'],
#   ['of', 'n'],
#   ['receivables', 'n'],
#   ['and', 'n'],
#   ['other', 'n'],
#   ['tax-related', 'n'],
#   ['items', 'n']],
#  [['lease', 'n'],
#   ['incentives', 'n'],
#   ['and', 'n'],
#   ['other', 'n'],
#   ['long-term', 'n'],
#   ['liabilities', 'n']],
#  [['operating', 'v'],
#   ['lease', 'n'],
#   ['assets', 'n'],
#   ['and', 'n'],
#   ['liabilities,', 'n'],
#   ['net', 'n']],
#  [['income', 'n'],
#   ['taxes', 'n'],
#   ['payable,', 'n'],
#   ['net', 'n'],
#   ['of', 'n'],
#   ['prepaid', 'n'],
#   ['and', 'n'],
#   ['other', 'n'],
#   ['tax-related', 'n'],
#   ['items', 'n']],
#  [['changeoperatingleaseassetandliabilitiesnet', 'n']],
#  [['other', 'n'], ['long-term', 'n'], ['liabilities', 'n']],
#  [['net', 'n'],
#   ['cash', 'n'],
#   ['provided', 'v'],
#   ['by', 'n'],
#   ['operating', 'n'],
#   ['activities', 'n']],
#  [['net', 'n'],
#   ['cash', 'n'],
#   ['provided', 'v'],
#   ['by', 'n'],
#   ['operating', 'n'],
#   ['activities', 'n']],
#  [['purchases', 'n'],
#   ['of', 'n'],
#   ['property', 'n'],
#   ['and', 'n'],
#   ['equipment', 'n']],
#  [['payments', 'n'],
#   ['to', 'n'],
#   ['acquire', 'n'],
#   ['short-term', 'n'],
#   ['investments', 'n']],
#  [['proceeds', 'n'],
#   ['from', 'n'],
#   ['sale,', 'n'],
#   ['maturity', 'n'],
#   ['and', 'n'],
#   ['collection', 'n'],
#   ['of', 'n'],
#   ['short-term', 'n'],
#   ['investments', 'n']],
#  [['payments', 'n'],
#   ['for', 'n'],
#   ['acquisition', 'n'],
#   ['activity,', 'n'],
#   ['net', 'n'],
#   ['of', 'n'],
#   ['cash', 'n'],
#   ['acquired', 'v']],
#  [['proceeds', 'n'],
#   ['from', 'n'],
#   ['sale', 'n'],
#   ['of', 'n'],
#   ['buildings', 'n']],
#  [['payments', 'n'],
#   ['to', 'n'],
#   ['acquire', 'n'],
#   ['businesses,', 'n'],
#   ['net', 'n'],
#   ['of', 'n'],
#   ['cash', 'n'],
#   ['acquired', 'n']],
#  [['payments', 'n'], ['to', 'n'], ['acquire', 'n'], ['buildings', 'n']],
#  [['other', 'n']],
#  [['sales', 'n'],
#   ['and', 'n'],
#   ['maturities', 'n'],
#   ['of', 'n'],
#   ['short-term', 'n'],
#   ['investments', 'n']],
#  [['insurance', 'n'],
#   ['proceeds', 'n'],
#   ['related', 'v'],
#   ['to', 'n'],
#   ['loss', 'n'],
#   ['on', 'n'],
#   ['property', 'n'],
#   ['and', 'n'],
#   ['equipment', 'n']],
#  [['purchase', 'n'], ['of', 'n'], ['building', 'n']],
#  [['proceeds', 'n'],
#   ['from', 'n'],
#   ['sale', 'n'],
#   ['of', 'n'],
#   ['building', 'n']],
#  [['purchases', 'n'], ['of', 'n'], ['short-term', 'n'], ['investments', 'n']],
#  [['proceeds', 'n'],
#   ['from', 'n'],
#   ['sales', 'n'],
#   ['and', 'n'],
#   ['maturities', 'n'],
#   ['of', 'n'],
#   ['short-term', 'n'],
#   ['investments', 'n']],
#  [['payments', 'n'],
#   ['to', 'n'],
#   ['acquire', 'n'],
#   ['property,', 'n'],
#   ['plant,', 'n'],
#   ['and', 'n'],
#   ['equipment', 'n']],
#  [['net', 'n'],
#   ['cash', 'n'],
#   ['paid', 'v'],
#   ['for', 'n'],
#   ['divestiture', 'n'],
#   ['activity', 'n']],
#  [['net', 'n'],
#   ['cash', 'n'],
#   ['provided', 'v'],
#   ['by', 'n'],
#   ['investing', 'v'],
#   ['activities', 'n']],
#  [['net', 'n'],
#   ['cash', 'n'],
#   ['used', 'v'],
#   ['for', 'n'],
#   ['investing', 'v'],
#   ['activities', 'n']],
#  [['net', 'n'],
#   ['cash', 'n'],
#   ['provided', 'n'],
#   ['by', 'n'],
#   ['investing', 'v'],
#   ['activities', 'n']],
#  [['other', 'n']],
#  [['payments', 'n'], ['to', 'n'], ['acquire', 'n'], ['buildings', 'n']],
#  [['net', 'n'],
#   ['cash', 'n'],
#   ['provided', 'v'],
#   ['by', 'n'],
#   ['investing', 'v'],
#   ['activities', 'n']],
#  [['net', 'n'],
#   ['cash', 'n'],
#   ['used', 'v'],
#   ['for', 'n'],
#   ['investing', 'v'],
#   ['activities', 'n']],
#  [['repayments', 'n'], ['of', 'n'], ['long-term', 'n'], ['debt', 'n']],
#  [['payments', 'n'],
#   ['of', 'n'],
#   ['debt', 'n'],
#   ['issuance', 'n'],
#   ['costs', 'n']],
#  [['payments', 'n'], ['of', 'n'], ['debt', 'n']],
#  [['other', 'n']],
#  [['excess', 'n'],
#   ['tax', 'n'],
#   ['benefit', 'n'],
#   ['from', 'n'],
#   ['exercise', 'n'],
#   ['of', 'n'],
#   ['stock', 'n'],
#   ['options', 'n'],
#   ['and', 'n'],
#   ['vesting', 'n'],
#   ['of', 'n'],
#   ['stock', 'n'],
#   ['units', 'n']],
#  [['proceeds', 'n'],
#   ['from', 'n'],
#   ['issuance', 'n'],
#   ['of', 'n'],
#   ['long-term', 'n'],
#   ['debt', 'n']],
#  [['payments', 'n'],
#   ['for', 'n'],
#   ['repurchase', 'n'],
#   ['of', 'n'],
#   ['common', 'n'],
#   ['stock', 'n']],
#  [['payments', 'n'], ['of', 'n'], ['dividends', 'n']],
#  [['net', 'n'],
#   ['cash', 'n'],
#   ['used', 'v'],
#   ['for', 'n'],
#   ['financing', 'n'],
#   ['activities', 'n']],
#  [['net', 'n'],
#   ['cash', 'n'],
#   ['provided', 'n'],
#   ['by', 'n'],
#   ['financing', 'n'],
#   ['activities,', 'n'],
#   ['total', 'n']],
#  [['proceeds', 'n'],
#   ['from', 'n'],
#   ['lines', 'n'],
#   ['of', 'n'],
#   ['credit', 'n']],
#  [['proceeds', 'n'],
#   ['from', 'n'],
#   ['issuances', 'n'],
#   ['under', 'n'],
#   ['share-based', 'n'],
#   ['compensation', 'n'],
#   ['plans', 'n']],
#  [['withholding', 'v'],
#   ['tax', 'n'],
#   ['payments', 'n'],
#   ['related', 'v'],
#   ['to', 'n'],
#   ['vesting', 'n'],
#   ['of', 'n'],
#   ['stock', 'n'],
#   ['units', 'n']],
#  [['repurchases', 'n'], ['of', 'n'], ['common', 'n'], ['stock', 'n']],
#  [['cash', 'n'], ['dividends', 'n'], ['paid', 'v']],
#  [['proceeds', 'n'],
#   ['from', 'n'],
#   ['issuance', 'n'],
#   ['of', 'n'],
#   ['long-term', 'n'],
#   ['debt', 'n']],
#  [['payments', 'n'], ['to', 'n'], ['extinguish', 'n'], ['debt', 'n']],
#  [['payments', 'n'],
#   ['for', 'n'],
#   ['debt', 'n'],
#   ['issuance', 'n'],
#   ['costs', 'n']],
#  [['repayments', 'n'],
#   ['of', 'n'],
#   ['lines', 'n'],
#   ['of', 'n'],
#   ['credit', 'n']],
#  [['effect', 'n'],
#   ['of', 'n'],
#   ['exchange', 'n'],
#   ['rate', 'n'],
#   ['on', 'n'],
#   ['cash,', 'n'],
#   ['cash', 'n'],
#   ['equivalents,', 'n'],
#   ['and', 'n'],
#   ['restricted', 'n'],
#   ['cash', 'n']],
#  [['proceeds', 'n'],
#   ['from', 'n'],
#   ['revolving', 'v'],
#   ['credit', 'n'],
#   ['facility', 'n']],
#  [['payments', 'n'],
#   ['for', 'n'],
#   ['revolving', 'v'],
#   ['credit', 'n'],
#   ['facility', 'n']],
#  [['payments', 'n'],
#   ['for', 'n'],
#   ['debt', 'n'],
#   ['issuance', 'n'],
#   ['costs', 'n']],
#  [['net', 'n'],
#   ['cash', 'n'],
#   ['provided', 'v'],
#   ['by', 'n'],
#   ['financing', 'n'],
#   ['activities', 'n']],
#  [['net', 'n'],
#   ['increase', 'n'],
#   ['in', 'n'],
#   ['cash,', 'n'],
#   ['cash', 'n'],
#   ['equivalents,', 'n'],
#   ['and', 'n'],
#   ['restricted', 'n'],
#   ['cash', 'n']],
#  [['effect', 'n'],
#   ['of', 'n'],
#   ['exchange', 'n'],
#   ['rate', 'n'],
#   ['on', 'n'],
#   ['cash,', 'n'],
#   ['cash', 'n'],
#   ['equivalents,', 'n'],
#   ['restricted', 'n'],
#   ['cash', 'n'],
#   ['and', 'n'],
#   ['restricted', 'n'],
#   ['cash', 'n'],
#   ['equivalents', 'n']],
#  [['cash,', 'n'],
#   ['cash', 'n'],
#   ['equivalents,', 'n'],
#   ['restricted', 'n'],
#   ['cash', 'n'],
#   ['and', 'n'],
#   ['restricted', 'n'],
#   ['cash', 'n'],
#   ['equivalents,', 'n'],
#   ['period', 'n'],
#   ['increase', 'n'],
#   ['(decrease),', 'n'],
#   ['including', 'n'],
#   ['exchange', 'n'],
#   ['rate', 'n'],
#   ['effect', 'n']],
#  [['cash,', 'n'],
#   ['cash', 'n'],
#   ['equivalents,', 'n'],
#   ['restricted', 'n'],
#   ['cash', 'n'],
#   ['and', 'n'],
#   ['restricted', 'n'],
#   ['cash', 'n'],
#   ['equivalents', 'n'],
#   ['beginning', 'n'],
#   ['of', 'n'],
#   ['period', 'n']],
#  [['cash,', 'n'],
#   ['cash', 'n'],
#   ['equivalents,', 'n'],
#   ['restricted', 'n'],
#   ['cash', 'n'],
#   ['and', 'n'],
#   ['restricted', 'n'],
#   ['cash', 'n'],
#   ['equivalents', 'n'],
#   ['end', 'n'],
#   ['of', 'n'],
#   ['period', 'n']],
#  [['proceeds', 'n'],
#   ['from', 'n'],
#   ['revolving', 'v'],
#   ['credit', 'n'],
#   ['facility', 'n']],
#  [['effect', 'n'],
#   ['of', 'n'],
#   ['foreign', 'n'],
#   ['exchange', 'n'],
#   ['rate', 'n'],
#   ['fluctuations', 'n'],
#   ['on', 'n'],
#   ['cash,', 'n'],
#   ['cash', 'n'],
#   ['equivalents,', 'n'],
#   ['and', 'n'],
#   ['restricted', 'v'],
#   ['cash', 'n']],
#  [['capital', 'n'],
#   ['expenditures', 'n'],
#   ['incurred', 'n'],
#   ['but', 'n'],
#   ['not', 'r'],
#   ['yet', 'r'],
#   ['paid', 'v']],
#  [['net', 'n'],
#   ['increase', 'n'],
#   ['in', 'n'],
#   ['cash,', 'n'],
#   ['cash', 'n'],
#   ['equivalents,', 'n'],
#   ['and', 'n'],
#   ['restricted', 'v'],
#   ['cash', 'n']],
#  [['interest', 'n'],
#   ['paid,', 'n'],
#   ['excluding', 'n'],
#   ['capitalized', 'n'],
#   ['interest,', 'n'],
#   ['operating', 'n'],
#   ['activities', 'n']],
#  [['cash,', 'n'],
#   ['cash', 'n'],
#   ['equivalents,', 'n'],
#   ['and', 'n'],
#   ['restricted', 'v'],
#   ['cash', 'n'],
#   ['at', 'n'],
#   ['beginning', 'v'],
#   ['of', 'n'],
#   ['period', 'n']],
#  [['cash,', 'n'],
#   ['cash', 'n'],
#   ['equivalents,', 'n'],
#   ['and', 'n'],
#   ['restricted', 'n'],
#   ['cash', 'n'],
#   ['end', 'n'],
#   ['of', 'n'],
#   ['period', 'n']],
#  [['purchases', 'n'],
#   ['of', 'n'],
#   ['property', 'n'],
#   ['and', 'n'],
#   ['equipment', 'n'],
#   ['not', 'r'],
#   ['yet', 'r'],
#   ['paid', 'v'],
#   ['at', 'n'],
#   ['end', 'n'],
#   ['of', 'n'],
#   ['period', 'n']],
#  [['cash', 'n'],
#   ['flow', 'n'],
#   ['non', 'n'],
#   ['cash', 'n'],
#   ['investing', 'n'],
#   ['disclosure', 'n'],
#   ['[abstract]', 'n']],
#  [['purchases', 'n'],
#   ['of', 'n'],
#   ['property', 'n'],
#   ['and', 'n'],
#   ['equipment', 'n'],
#   ['not', 'r'],
#   ['yet', 'r'],
#   ['paid', 'v'],
#   ['at', 'n'],
#   ['end', 'n'],
#   ['of', 'n'],
#   ['period', 'n']],
#  [['interest', 'n'],
#   ['paid,', 'n'],
#   ['including', 'n'],
#   ['capitalized', 'n'],
#   ['interest,', 'n'],
#   ['operating', 'n'],
#   ['and', 'n'],
#   ['investing', 'n'],
#   ['activities', 'n']],
#  [['income', 'n'], ['taxes', 'n'], ['paid', 'v']],
#  [['cash', 'n'],
#   ['paid', 'v'],
#   ['for', 'n'],
#   ['income', 'n'],
#   ['taxes', 'n'],
#   ['during', 'n'],
#   ['the', 'n'],
#   ['period,', 'n'],
#   ['net', 'n'],
#   ['of', 'n'],
#   ['refunds', 'n']],
#  [['cash', 'n'],
#   ['paid', 'v'],
#   ['for', 'n'],
#   ['interest', 'n'],
#   ['during', 'n'],
#   ['the', 'n'],
#   ['period', 'n']],
#  [['operating', 'v'], ['lease,', 'n'], ['payments', 'n']],
#  [['cash', 'n'],
#   ['paid', 'v'],
#   ['for', 'n'],
#   ['operating', 'n'],
#   ['lease', 'n'],
#   ['liabilities', 'n']]]

# %%
# Out:
# [('Hi', 'NN')]
