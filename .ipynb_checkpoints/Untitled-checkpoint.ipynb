# %%
import pandas as pd
import os
import openpyxl
import numpy as np
import re

# %%
files = os.listdir("financial statements")
files.remove(".DS_Store")
files = [file for file in files if file[0] != "~"]

finalBalance
# Out:
# Empty DataFrame
# Columns: [labels]
# Index: []

# %%
class FinancialReport():
    def __init__(self,file):
        self.file = file
        self.readFile()
        self.findBalanceSheet()
    def readFile(self):
        path = os.path.join("financial statements",self.file)
        self.statements = pd.read_excel(path,sheet_name=None)
    def getSheetNames(self):
        return self.statements.keys()
    def findBalanceSheet(self):
        balanceSheetName = [name for name in self.getSheetNames() if "BALANCE" in name][0]
        self.balance = self.statements[balanceSheetName]
        self.balance.columns = ["labels"]+list(self.balance.columns[1:])
    def getBalanceSheet(self):
        return self.balance

# %%
def titles(balance):
    index = []
    for label in balance.labels:
        if ":" in label:
            title = label[:-1]
            continue
        index.append([title,label])
    balance = balance.loc[balance.labels.isin(np.array(index)[:,1])].copy()
    balance.loc[:,["title","labels"]] = list(index)
    return balance

# %%
finalBalance = pd.DataFrame(columns=["title","labels"])
for file in files[:2]:
    print(file)
    statements = FinancialReport(file)
    balance = statements.getBalanceSheet()
    cols = ["labels"]+[col for col in balance.columns[1:] if col not in finalBalance.columns]
    #balance = balance.iloc[:balance[balance["labels"]=="Total liabilities and stockholders' equity"].index[0]+1]
    balance = balance.copy()
    balance = balance[cols]
    balance.loc[:,"labels"] = [re.sub("\$|\d+\,*", "", label) if np.any([char.isdigit() for char in label]) else label for label in balance["labels"]  ]
    balance = titles(balance)
    finalBalance = pd.merge(finalBalance, balance, how="outer",on=["title","labels"])
    finalBalance
# Out:
# q3 2021.xlsx
# q3 2020.xlsx

# %%
list(finalBalance.labels)
# Out:
# ['Cash and cash equivalents',
#  'Short-term investments',
#  'Merchandise inventory',
#  'Other current assets',
#  'Total current assets',
#  'Property and equipment, net of accumulated depreciation',
#  'Operating Lease, Right-of-Use Asset',
#  'Other long-term assets',
#  'Total assets',
#  'Accounts payable',
#  'Accrued expenses and other current liabilities',
#  'Operating Lease, Liability, Current',
#  'Income taxes payable',
#  'Total current liabilities',
#  'Total long-term debt',
#  'Operating Lease, Liability, Noncurrent',
#  'Lease incentives and other long-term liabilities',
#  'Total long-term liabilities',
#  'Commitments and contingencies (see Note )',
#  'Common stock, shares outstanding (in shares)',
#  'Authorized  shares for all periods presented',
#  'Additional Paid in Capital',
#  'Retained earnings',
#  'Amounts reclassified from accumulated other comprehensive income',
#  "Total stockholders' equity",
#  "Total liabilities and stockholders' equity",
#  'Property and equipment, accumulated depreciation',
#  'Common stock, shares issued (in shares)',
#  'Common stock, shares authorized (in shares)',
#  'Common stock, par value (in dollars per share)',
#  'Available-for-sale Securities, Current',
#  'Property and equipment, net of accumulated depreciation of   and ',
#  'Authorized  shares for all periods presented; Issued and Outstanding   and  shares']

# %%
balance = balance.copy()
balance.loc[:,'labels']=here
balance
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [297], in <cell line: 2>()
#       1 balance = balance.copy()
# ----> 2 balance.loc[:,'labels']=here
#       3 balance
#
# File /usr/local/lib/python3.9/site-packages/pandas/core/indexing.py:716, in _LocationIndexer.__setitem__(self, key, value)
#     713 self._has_valid_setitem_indexer(key)
#     715 iloc = self if self.name == "iloc" else self.obj.iloc
# --> 716 iloc._setitem_with_indexer(indexer, value, self.name)
#
# File /usr/local/lib/python3.9/site-packages/pandas/core/indexing.py:1690, in _iLocIndexer._setitem_with_indexer(self, indexer, value, name)
#    1688     self._setitem_with_indexer_split_path(indexer, value, name)
#    1689 else:
# -> 1690     self._setitem_single_block(indexer, value, name)
#
# File /usr/local/lib/python3.9/site-packages/pandas/core/indexing.py:1920, in _iLocIndexer._setitem_single_block(self, indexer, value, name)
#    1917     if len(item_labels.get_indexer_for([col])) == 1:
#    1918         # e.g. test_loc_setitem_empty_append_expands_rows
#    1919         loc = item_labels.get_loc(col)
# -> 1920         self.obj._iset_item(loc, value)
#    1921         return
#    1923 indexer = maybe_convert_ix(*indexer)  # e.g. test_setitem_frame_align
#
# File /usr/local/lib/python3.9/site-packages/pandas/core/frame.py:3813, in DataFrame._iset_item(self, loc, value)
#    3812 def _iset_item(self, loc: int, value) -> None:
# -> 3813     arraylike = self._sanitize_column(value)
#    3814     self._iset_item_mgr(loc, arraylike, inplace=True)
#    3816     # check if we are modifying a copy
#    3817     # try to set first as we want an invalid
#    3818     # value exception to occur first
#
# File /usr/local/lib/python3.9/site-packages/pandas/core/frame.py:4535, in DataFrame._sanitize_column(self, value)
#    4532     return _reindex_for_setitem(value, self.index)
#    4534 if is_list_like(value):
# -> 4535     com.require_length_match(value, self.index)
#    4536 return sanitize_array(value, self.index, copy=True, allow_2d=True)
#
# File /usr/local/lib/python3.9/site-packages/pandas/core/common.py:557, in require_length_match(data, index)
#     553 """
#     554 Check the length of data matches the length of the index.
#     555 """
#     556 if len(data) != len(index):
# --> 557     raise ValueError(
#     558         "Length of values "
#     559         f"({len(data)}) "
#     560         "does not match length of index "
#     561         f"({len(index)})"
#     562     )
#
# ValueError: Length of values (34) does not match length of index (30)

# %%
balance.loc[:, "labels"]="t"
# Out:
# /var/folders/s3/62ngj7ts6qgfyfjmjw2vrx_00000gp/T/ipykernel_54395/1833132588.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   balance.loc[:, "labels"]="t"

# %%
finalBalance.labels
# Out:
# 0                                       Current assets:
# 1                             Cash and cash equivalents
# 2                                Short-term investments
# 3                                 Merchandise inventory
# 4                                  Other current assets
# 5                                  Total current assets
# 6     Property and equipment, net of accumulated dep...
# 7                   Operating Lease, Right-of-Use Asset
# 8                                Other long-term assets
# 9                                          Total assets
# 10                                 Current liabilities:
# 11                                     Accounts payable
# 12       Accrued expenses and other current liabilities
# 13                  Operating Lease, Liability, Current
# 14                                 Income taxes payable
# 15                            Total current liabilities
# 16                               Long-term liabilities:
# 17                                 Total long-term debt
# 18               Operating Lease, Liability, Noncurrent
# 19     Lease incentives and other long-term liabilities
# 20                          Total long-term liabilities
# 21            Commitments and contingencies (see Note )
# 22         Common stock, shares outstanding (in shares)
# 23                                Stockholders' equity:
# 24         Authorized  shares for all periods presented
# 25                           Additional Paid in Capital
# 26                                    Retained earnings
# 27    Amounts reclassified from accumulated other co...
# 28                           Total stockholders' equity
# 29           Total liabilities and stockholders' equity
# 30               Available-for-sale Securities, Current
# 31    Property and equipment, net of accumulated dep...
# 32    Authorized  shares for all periods presented; ...
# 33                               Short-term Investments
# 34    Property and equipment, net of accumulated dep...
# 35                                       Long-term debt
# 36    Common stock . par value, Authorized  shares f...
# 37               Accumulated other comprehensive income
# 38    Line of Credit Facility, Fair Value of Amount ...
# 39                           Current maturities of debt
# 40    Accumulated Depreciation, Depletion and Amorti...
# 41                               Operating lease assets
# 42       Current portion of operating lease liabilities
# 43                Long-term operating lease liabilities
# 44                          Other long-term liabilities
# 45    Common stock . par value, Authorized  shares f...
# 46         Cash and Cash Equivalents, at Carrying Value
# 47                                Other Assets, Current
# 48                         Accrued Liabilities, Current
# Name: labels, dtype: object

# %%
# Out:
# 'Authorized  shares for all periods presented'

# %%
statements = FinancialReport(files[0])
balance1 = statements.getBalanceSheet()
statements = FinancialReport(files[1])
balance2 = statements.getBalanceSheet()
final_balance = pd.merge(finalBalance, balance1, how="outer",on="labels")
final_balance = pd.merge(finalBalance, balance2, how="outer",on="labels")
# Out:
#                                                labels Oct. 31, 2020  \
# 0                                     Current assets:           NaN
# 1                           Cash and cash equivalents          2471
# 2              Available-for-sale Securities, Current           178
# 3                               Merchandise inventory          2747
# 4                                Other current assets           966
# 5                                Total current assets          6362
# 6   Property and equipment, net of accumulated dep...          2846
# 7                 Operating Lease, Right-of-Use Asset          4460
# 8                              Other long-term assets           705
# 9                                        Total assets         14373
# 10                               Current liabilities:           NaN
# 11                                   Accounts payable          2284
# 12     Accrued expenses and other current liabilities          1283
# 13                Operating Lease, Liability, Current           823
# 14                               Income taxes payable            41
# 15                          Total current liabilities          4431
# 16                             Long-term liabilities:           NaN
# 17                               Total long-term debt          2214
# 18   Lease incentives and other long-term liabilities           458
# 19             Operating Lease, Liability, Noncurrent          4899
# 20                        Total long-term liabilities          7571
# 21         Commitments and contingencies (see Note 9)
# 22       Common stock, shares outstanding (in shares)        374000
# 23                              Stockholders' equity:           NaN
# 24  Authorized 2,300 shares for all periods presen...            19
# 25                         Additional Paid in Capital            60
# 26                                  Retained earnings          2268
# 27  Amounts reclassified from accumulated other co...            24
# 28                         Total stockholders' equity          2371
# 29         Total liabilities and stockholders' equity         14373
# 30   Property and equipment, accumulated depreciation          5891
# 31            Common stock, shares issued (in shares)        374000
# 32        Common stock, shares authorized (in shares)       2300000
# 33     Common stock, par value (in dollars per share)         50000
#
#    Feb. 01, 2020 Nov. 02, 2019
# 0            NaN           NaN
# 1           1364           788
# 2            290           294
# 3           2156          2720
# 4            706           770
# 5           4516          4572
# 6           3122          3225
# 7           5402          5796
# 8            639           525
# 9          13679         14118
# 10           NaN           NaN
# 11          1174          1241
# 12          1067           974
# 13           920           934
# 14            48            43
# 15          3209          3192
# 16           NaN           NaN
# 17          1249          1249
# 18           397           393
# 19          5508          5650
# 20          7154          7292
# 21
# 22        371000        373000
# 23           NaN           NaN
# 24            19            19
# 25             0             0
# 26          3257          3573
# 27            40            42
# 28          3316          3634
# 29         13679         14118
# 30          5839          5999
# 31        371000        373000
# 32       2300000       2300000
# 33         50000         50000

# %%
balance1.columns
# Out:
# Index(['labels', 'Oct. 31, 2020', 'Feb. 01, 2020', 'Nov. 02, 2019'], dtype='object')

# %%
balance2.columns
# Out:
# Index(['labels', 'Oct. 31, 2020', 'Feb. 01, 2020', 'Nov. 02, 2019'], dtype='object')

# %%
final_balance = pd.merge(finalBalance, balance, how="outer",on="labels")

# %%
final_balance
# Out:
#                                                labels  Jan. 30, 2021  \
# 0                                     Current assets:            NaN
# 1        Cash and Cash Equivalents, at Carrying Value        1988.00
# 2                              Short-term Investments         410.00
# 3                               Merchandise inventory        2451.00
# 4                               Other Assets, Current        1159.00
# 5                                Total current assets        6008.00
# 6   Accumulated Depreciation, Depletion and Amorti...        5608.00
# 7   Property and equipment, net of accumulated dep...        2841.00
# 8                 Operating Lease, Right-of-Use Asset        4217.00
# 9                              Other long-term assets         703.00
# 10                                       Total assets       13769.00
# 11                               Current liabilities:            NaN
# 12                                   Accounts payable        1743.00
# 13                       Accrued Liabilities, Current        1276.00
# 14                Operating Lease, Liability, Current         831.00
# 15                               Income taxes payable          34.00
# 16                          Total current liabilities        3884.00
# 17                             Long-term liabilities:            NaN
# 18                                     Long-term debt        2216.00
# 19             Operating Lease, Liability, Noncurrent        4617.00
# 20                        Other long-term liabilities         438.00
# 21                        Total long-term liabilities        7271.00
# 22                              Stockholders' equity:            NaN
# 23  Common stock $0.05 par value, Authorized 2,300...          19.00
# 24                         Additional Paid in Capital          85.00
# 25                                  Retained earnings        2501.00
# 26             Accumulated other comprehensive income           9.00
# 27                         Total stockholders' equity        2614.00
# 28         Total liabilities and stockholders' equity       13769.00
# 29     Common stock, par value (in dollars per share)           0.05
# 30       Common stock, shares outstanding (in shares)      374000.00
# 31            Common stock, shares issued (in shares)      374000.00
# 32        Common stock, shares authorized (in shares)     2300000.00
#
#     Feb. 01, 2020
# 0             NaN
# 1         1364.00
# 2          290.00
# 3         2156.00
# 4          706.00
# 5         4516.00
# 6         5839.00
# 7         3122.00
# 8         5402.00
# 9          639.00
# 10       13679.00
# 11            NaN
# 12        1174.00
# 13        1067.00
# 14         920.00
# 15          48.00
# 16        3209.00
# 17            NaN
# 18        1249.00
# 19        5508.00
# 20         397.00
# 21        7154.00
# 22            NaN
# 23          19.00
# 24           0.00
# 25        3257.00
# 26          40.00
# 27        3316.00
# 28       13679.00
# 29           0.05
# 30      371000.00
# 31      371000.00
# 32     2300000.00

# %%
balance
# Out:
#    labels Feb. 01, 2020 Nov. 02, 2019
# 0       t           NaN           NaN
# 1       t          1364           788
# 2       t           290           294
# 3       t          2156          2720
# 4       t           706           770
# 5       t          4516          4572
# 6       t          3122          3225
# 7       t          5402          5796
# 8       t           639           525
# 9       t         13679         14118
# 10      t           NaN           NaN
# 11      t          1174          1241
# 12      t          1067           974
# 13      t           920           934
# 14      t            48            43
# 15      t          3209          3192
# 16      t           NaN           NaN
# 17      t          1249          1249
# 18      t           397           393
# 19      t          5508          5650
# 20      t          7154          7292
# 21      t
# 22      t        371000        373000
# 23      t           NaN           NaN
# 24      t            19            19
# 25      t             0             0
# 26      t          3257          3573
# 27      t            40            42
# 28      t          3316          3634
# 29      t         13679         14118
# 30      t          5839          5999
# 31      t        371000        373000
# 32      t       2300000       2300000
# 33      t         50000         50000

# %%
# #data = pd.DataFrame({"h":[1,2,2],"t":[83,2,9]})
# balance.loc[:, 't'] = 100
balance = balance.copy()
balance.loc[:,'labels']=10028
balance
# Out:
#     labels Feb. 01, 2020 Nov. 02, 2019      k
# 0    10028           NaN           NaN  10028
# 1    10028          1364           788  10028
# 2    10028           290           294  10028
# 3    10028          2156          2720  10028
# 4    10028           706           770  10028
# 5    10028          4516          4572  10028
# 6    10028          3122          3225  10028
# 7    10028          5402          5796  10028
# 8    10028           639           525  10028
# 9    10028         13679         14118  10028
# 10   10028           NaN           NaN  10028
# 11   10028          1174          1241  10028
# 12   10028          1067           974  10028
# 13   10028           920           934  10028
# 14   10028            48            43  10028
# 15   10028          3209          3192  10028
# 16   10028           NaN           NaN  10028
# 17   10028          1249          1249  10028
# 18   10028           397           393  10028
# 19   10028          5508          5650  10028
# 20   10028          7154          7292  10028
# 21   10028                              10028
# 22   10028        371000        373000  10028
# 23   10028           NaN           NaN  10028
# 24   10028            19            19  10028
# 25   10028             0             0  10028
# 26   10028          3257          3573  10028
# 27   10028            40            42  10028
# 28   10028          3316          3634  10028
# 29   10028         13679         14118  10028
# 30   10028          5839          5999  10028
# 31   10028        371000        373000  10028
# 32   10028       2300000       2300000  10028
# 33   10028         50000         50000  10028

# %%
    balance = balance.iloc[:balance[balance["labels"]=="Total liabilities and stockholders' equity"].index[0]+1]
